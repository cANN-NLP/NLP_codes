# %% [markdown]
# **Prediction of the next word by the preceeding 16 words**
#
# This preprocessing is based on Dict 2.5 (Keiko updated).

# %%
ver = 21213;

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd "gdrive/My Drive/Colab/NLP"
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# [Errno 2] No such file or directory: 'gdrive/My Drive/Colab/NLP'
# /content/gdrive/My Drive/Colab/NLP

# %%
import numpy as np
np.set_printoptions(threshold=np.inf)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import preprocessing

# %%
print(tf.__version__)
# Out:
# 2.11.0

# %%
#### load text data file #####
import nltk

# %%
nltk.download('gutenberg')
# nltk.corpus.gutenberg.fileids()
text_=[]
text_.append( nltk.corpus.gutenberg.raw('carroll-alice.txt') )
text_.append( nltk.corpus.gutenberg.raw('austen-emma.txt') )
text_.append( nltk.corpus.gutenberg.raw('austen-persuasion.txt') )
text_.append( nltk.corpus.gutenberg.raw('austen-sense.txt') )
text_.append( nltk.corpus.gutenberg.raw('melville-moby_dick.txt') )
text_.append( nltk.corpus.gutenberg.raw('burgess-busterbrown.txt') ) # children's book, "The Adventures of Buster Bear" "Fun with Farmer Brown's Boy"
text_.append( nltk.corpus.gutenberg.raw('edgeworth-parents.txt') ) # children's book, "The Parent's Assistant", 1796
text_br = nltk.corpus.gutenberg.raw('bryant-stories.txt')  # "Stories to Tell to Children", by Sara Cone Bryant 1918
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!

# %%
# nltk.corpus.gutenberg.fileids()

# %%
txt_1 = """My name is Anne. I am a Japanese high school student. I came to live in America with my family two weeks ago. One day Mother asked me about my school life. I answered that I enjoyed it very much. But that was not true. I didn't want Mother to worry about me. I always said to myself, "I live in two worlds, one at home and the other at school. They are very different. At home I speak Japanese and live a happy Japanese life with my family. I feel that school is far away when I am at home. In class at school teachers sometimes speak English so fast that I don't understand them. I want to talk with a friend about that, but I don't have any friends. Every day I wait for a student who will talk to me." The next day in art class the teacher stopped at my desk and said, "Akiko, your picture is very wonderful! " Then many students came to see my picture. After the art class one girl student came to me. At last a student talked to me! She said, "Hi, Anne. I'm Suzzan. I would like to talk with you after school." I was very happy. I said, "Yes, of course." After school we went to Mary's house and began to talk. Mary was also interested in drawing pictures. We talked about a lot of things. When I talked about my idea of the two worlds, Mary said, "I didn't know that. But you can ask teachers to speak more slowly. If you want to make your school life happy, you should try to say something to us. We will help you any time." I had a very good time with Mary. I ran home to tell Mother about my new friend, but she was not there. Soon Mother came home. "Mother, where have you been? "I asked. "I have been to English school. I began to learn English, " answered Mother. "You don't have to learn English so hard because you stay home every day, " I said. "I want to make friends to learn about America and tell them a lot about Japan, " said Mother. "Mary and Mother have the same idea, " I thought. " Today I learned an important thing from Mary and Mother. It is not good to stay in our small world when we are in a foreign culture. I will try hard to make my school life happy."
Relearning the art of seeing the world around us is quite simple, although it takes practice and requires breaking some bad abits. And "relearn" is the correct word. Most of us observed much more as children than we do as adults. A child's day is filled with newness and wonder. The desire to explore, to have an adventure, gave us all a natural ability to be aware of the world around us.
But as adults we are slow to be stimulated by new ideas and new situations. We fail to see the wonder of the things around us. The first step in awakening our senses is to rediscover the ability to observe that we had as children. To do so we need to stop anticipating what we are going to see and feel before it happens. Such anticipation blocks our ability to feel. For example, one chilly night I was on a mountain hike with some students. I told them that we were going to have to cross a mountain stream. They began to grumble about how cold it would be. We reached the stream and they reluctantly plunged ahead. They were almost up to their knees in the water when they realized that I had led them into a hot spring. Later they all said that they had felt cold water at first. We also need to notice signs which can help us see more. Once I was on a hike, following about six meters behind my Indian friend named John. As we passed under a huge pine tree. he turned around and said, "Don't disturb it." Surprised, I looked everywhere. Was there a deer, a fox, or something else that I had missed seeing? Finally I looked into the branches of the tree and saw a beautiful owl not three meters from us. I was amazed that Stalking Wolf had known it was there without looking up. When I asked him how he had known the owl was there, he replied, "Go ask the mice." By looking down he had seen the tracks of the mice that had run away from their dreaded enemy, the owl. The next time you take a walk, no matter where it is, open up your eyes. Be aware of all the sights, sounds and sensations. You will be surprised at the many beautiful and interesting things you have been missing. """

# %%
text_br = text_br.replace("Here's", "Here is");   text_br = text_br.replace("here's", "here is");   text_br = text_br.replace("I'm", "I am");   text_br = text_br.replace("I'd", "I would");   text_br = text_br.replace("I've", "I have");   text_br = text_br.replace("I'll", "I will");    text_br = text_br.replace("that's", "that is");   text_br = text_br.replace("That's", "That is");     text_br = text_br.replace("What's", "What is");   text_br = text_br.replace("You'll", "You will");   text_br = text_br.replace("you'll", "you will");  text_br = text_br.replace("It's", "It is");   text_br = text_br.replace("it's", "it is");  text_br = text_br.replace("It'll", "It will");   text_br = text_br.replace("it'll", "it will");  text_br = text_br.replace("You're", "You are");  text_br = text_br.replace("you're", "you are");   text_br = text_br.replace("You've", "You have");  text_br = text_br.replace("you've", "you have");   text_br = text_br.replace("You've", "You have");
text_br = text_br.replace("We'll", "We will");   text_br = text_br.replace("we'll", "we will");  text_br = text_br.replace("She'll", "She will");   text_br = text_br.replace("she'll", "she will");  text_br = text_br.replace("He'll", "He will");  text_br = text_br.replace("he'll", "he will");  text_br = text_br.replace("They'll", "They will");  text_br = text_br.replace("they'll", "they will");   text_br = text_br.replace("They're", "They are");  text_br = text_br.replace("they're", "they are");  text_br = text_br.replace("They've", "They have");  text_br = text_br.replace("they've", "they have");
text_br = text_br.replace("don't", "do not");   text_br = text_br.replace("doesn't", "does not");   text_br = text_br.replace("didn't", "did not");   text_br = text_br.replace("isn't", "is not");   text_br = text_br.replace("wasn't", "was not");   text_br = text_br.replace("aren't", "are not");  text_br = text_br.replace("hasn't", "has not");    text_br = text_br.replace("haven't", "have not");  text_br = text_br.replace("hadn't", "had not");   text_br = text_br.replace("won't", "will not");
text_br = text_br.replace("can't", "can not");  text_br = text_br.replace("cannot", "can not");  text_br = text_br.replace("shouldn't", "should not");  text_br = text_br.replace("wouldn't", "would not");  text_br = text_br.replace(" Miss ", " dr ");    text_br = text_br.replace(" Pip ", " john ");
text_br = text_br.replace("'", "");     # for 'bryant-stories.txt'

# %%
text = ''
for i in range(len(text_)):     text = text + text_[i]
text = text + text_br + txt_1

# %%
text = text.replace('\r\n', ' ');  text = text.replace('\n', ' ');   # \n is inserted not at the end of sentence.
text = text.replace("Here's", "Here is");   text = text.replace("here's", "here is");   text = text.replace("I'm", "I am");   text = text.replace("I'd", "I would");   text = text.replace("I've", "I have");   text = text.replace("I'll", "I will");    text = text.replace("that's", "that is");   text = text.replace("That's", "That is");     text = text.replace("What's", "What is");
text = text.replace("We'll", "We will");   text = text.replace("we'll", "we will");  text = text.replace("You'll", "You will");   text = text.replace("you'll", "you will");  text = text.replace("It's", "It is");   text = text.replace("it's", "it is");  text = text.replace("It'll", "It will");   text = text.replace("it'll", "it will");  text = text.replace("You're", "You are");  text = text.replace("you're", "you are");   text = text.replace("You've", "You have");  text = text.replace("you've", "you have");   text = text.replace("You've", "You have");
text = text.replace("She'll", "She will");   text = text.replace("she'll", "she will");  text = text.replace("He'll", "He will");  text = text.replace("he'll", "he will");  text = text.replace("They'll", "They will");  text = text.replace("they'll", "they will");   text = text.replace("They're", "They are");  text = text.replace("they're", "they are");  text = text.replace("They've", "They have");  text = text.replace("they've", "they have");
text = text.replace("don't", "do not");   text = text.replace("doesn't", "does not");   text = text.replace("didn't", "did not");   text = text.replace("isn't", "is not");   text = text.replace("wasn't", "was not");   text = text.replace("aren't", "are not");  text = text.replace("hasn't", "has not");    text = text.replace("haven't", "have not");  text = text.replace("hadn't", "had not");   text = text.replace("won't", "will not");  text = text.replace("can't", "can not");  text = text.replace("cannot", "can not");  text = text.replace("shouldn't", "should not");  text = text.replace("wouldn't", "would not");
text = text.replace("gonna", "going to");   text = text.replace("wanna", "want to");   text = text.replace(" Miss ", " dr ");   text = text.replace(" Pip ", " john ");
# text = text.replace("'", "");  # for 'bryant-stories.txt'

# %%
nltk.download('punkt')
text = nltk.tokenize.sent_tokenize(text) ## generating sentenses
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
##### preprocessing: selecting sentences #####
import re
sents1 = [];
for line in range(len(text)):
    words = text[line].split()    # text[line] will be converted to lists of words
    if (len(words) >= 3):
        line_s = re.split(r'[:;]',text[line]);
        if len(line_s)>1:        ## finding multiple sentenses in one line
            for i in range(len(line_s)):
                if len(line_s[i])>4:    sents1.append(line_s[i])
        else:  sents1.append(text[line]);

# %%
nltk.download('brown')
text_b,sents2=[],[]
text_b.append( nltk.corpus.brown.sents(categories='adventure') )
text_b.append( nltk.corpus.brown.sents(categories='news') )
text_b.append( nltk.corpus.brown.sents(categories='belles_lettres') )
text_b.append( nltk.corpus.brown.sents(categories='humor') )
text_b.append( nltk.corpus.brown.sents(categories='hobbies') )
text_b.append( nltk.corpus.brown.sents(categories='reviews') )
text_b.append( nltk.corpus.brown.sents(categories='romance') )
text_b.append( nltk.corpus.brown.sents(categories='science_fiction') )
text_b.append( nltk.corpus.brown.sents(categories='mystery') )
text_b.append( nltk.corpus.brown.sents(categories='fiction') )

for i in range(len(text_b)):
    for ln in range(len(text_b[i])):
        line = ' '.join(text_b[i][ln]) ## text_b is lists of words (in brown corpus)
        line = line.replace("Here's", "Here is");   line = line.replace("here's", "here is");   line = line.replace("I'm", "I am");   line = line.replace("I'd", "I would");   line = line.replace("I've", "I have");   line = line.replace("I'll", "I will");    line = line.replace("that's", "that is");   line = line.replace("That's", "That is");     line = line.replace("What's", "What is");   line = line.replace("there's", "there is");   line = line.replace("There's", "There is");
        line = line.replace("We'll", "We will");   line = line.replace("we'll", "we will");  line = line.replace("You'll", "You will");   line = line.replace("you'll", "you will");  line = line.replace("It's", "It is");   line = line.replace("it's", "it is");  line = line.replace("It'll", "It will");   line = line.replace("it'll", "it will");  line = line.replace("You're", "You are");  line = line.replace("you're", "you are");   line = line.replace("You've", "You have");  line = line.replace("you've", "you have");   line = line.replace("You've", "You have");
        line = line.replace("She'll", "She will");   line = line.replace("she'll", "she will");  line = line.replace("He'll", "He will");  line = line.replace("he'll", "he will");  line = line.replace("They'll", "They will");  line = line.replace("they'll", "they will");   line = line.replace("They're", "They are");  line = line.replace("they're", "they are");  line = line.replace("They've", "They have");  line = line.replace("they've", "they have");
        line = line.replace("don't", "do not");   line = line.replace("doesn't", "does not");   line = line.replace("didn't", "did not");   line = line.replace("isn't", "is not");   line = line.replace("wasn't", "was not");   line = line.replace("aren't", "are not");  line = line.replace("hasn't", "has not");    line = line.replace("haven't", "have not");  line = line.replace("hadn't", "had not");   line = line.replace("won't", "will not");  line = line.replace("can't", "can not");  line = line.replace("cannot", "can not");  line = line.replace("shouldn't", "should not");  line = line.replace("couldn't", "could not");  line = line.replace("wouldn't", "would not");
        line = line.replace("gonna", "going to");   line = line.replace("wanna", "want to");     line = line.replace(" Miss ", " dr ");   line = line.replace(" Pip ", " john ");
        sents2.append(line)

sents = sents2 + sents1
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!

# %%
######## remove text within parentheses ############
for i in range(len(sents)):
    sents[i] = re.sub("[\(\[].*?[\)\]]", "", sents[i])
    sents[i] = re.sub(r"[0-9]+", "0", sents[i])

# %%
for i in range(len(sents)):
    if (type(sents[i]) != str):  continue
    sents[i] = sents[i].lower()
    sents[i] = ' ' + sents[i]
    sents[i] = sents[i].replace("'s", "s ");  sents[i] = sents[i].replace("'twas", " it was ");
    sents[i] = sents[i].replace("have'n't", " have not ");   sents[i] = sents[i].replace("ev'n", " even ");
    sents[i] = sents[i].replace("o'er", " over ");   sents[i] = sents[i].replace("sha'n't", " shall not ");
    sents[i] = sents[i].replace("""'""", "");
    sents[i] = sents[i].replace(".", " "); sents[i] = sents[i].replace("?", " ");  sents[i] = sents[i].replace("!", " ");    sents[i] = sents[i].replace(""" " """, """ """);  sents[i] = sents[i].replace("&", " and ");
    sents[i] = sents[i].replace('''"''', ' " ');
    sents[i] = sents[i].replace("*", " ");  sents[i] = sents[i].replace("_", " ");sents[i] = sents[i].replace("`", " ");  sents[i] = sents[i].replace(",", " ");  sents[i] = sents[i].replace(".", " ");   sents[i] = sents[i].replace(";", " ");  sents[i] = sents[i].replace(":", " ");  sents[i] = sents[i].replace("?", " ");  sents[i] = sents[i].replace("!", " ");
    sents[i] = sents[i].replace("&", " and "); sents[i] = sents[i].replace('''"''', ' " ');   sents[i] = sents[i].replace(""" " " """, """ " """);

    sents[i] = sents[i].replace("- -", "--");  sents[i] = sents[i].replace("----", "--");  sents[i] = sents[i].replace("--", " -- ");
    sents[i] = sents[i].replace(" 0-", " 0 ");  sents[i] = sents[i].replace("0", " 0 ");  sents[i] = sents[i].replace("  ", " ");  sents[i] = sents[i].replace("  ", " ");  sents[i] = sents[i].replace(" 0 d ", " 0 ");  sents[i] = sents[i].replace(" 0 s ", " 0 ");  sents[i] = sents[i].replace(" 0 st ", " 0 ");  sents[i] = sents[i].replace(" 0 th ", " 0 ");  sents[i] = sents[i].replace(" 0 0 ", " 0 ");  sents[i] = sents[i].replace(" 0 0 ", " 0 ");  sents[i] = sents[i].replace(" 0 0 ", " 0 ");  sents[i] = sents[i].replace(" $ 0 0 ", " 0 dollar ");  sents[i] = sents[i].replace(" $ 0 ", " 0 dollar ");
    sents[i] = sents[i].replace("   ", " ");  sents[i] = sents[i].replace("   ", " ");  sents[i] = sents[i].replace("   ", " ");  sents[i] = sents[i].replace(" 0 ", " zero ");
    sents[i] = sents[i].replace(" b ", " ");   sents[i] = sents[i].replace(" c ", " ");  sents[i] = sents[i].replace(" d ", " ");  sents[i] = sents[i].replace(" e ", " ");  sents[i] = sents[i].replace(" f ", " ");  sents[i] = sents[i].replace(" g ", " ");  sents[i] = sents[i].replace(" h ", " ");  sents[i] = sents[i].replace(" j ", " ");  sents[i] = sents[i].replace(" k ", " ");  sents[i] = sents[i].replace(" l ", " ");  sents[i] = sents[i].replace(" m ", " ");   sents[i] = sents[i].replace(" n ", " ");   sents[i] = sents[i].replace(" o ", " ");   sents[i] = sents[i].replace(" p ", " ");  sents[i] = sents[i].replace(" q ", " ");  sents[i] = sents[i].replace(" r ", " ");  sents[i] = sents[i].replace(" s ", " ");   sents[i] = sents[i].replace(" t ", " ");  sents[i] = sents[i].replace(" u ", " ");   sents[i] = sents[i].replace(" v ", " ");  sents[i] = sents[i].replace(" w ", " ");  sents[i] = sents[i].replace(" z ", " ");

    sents[i] = sents[i].replace(" pre-", " pre"); sents[i] = sents[i].replace(" mama ", " mother "); sents[i] = sents[i].replace(" em ", " them ");  sents[i] = sents[i].replace(" morrow ", " tomorrow "); sents[i] = sents[i].replace(" to-morrow", " tomorrow")
    sents[i] = sents[i].replace(" de ", "  ");  sents[i] = sents[i].replace(" don ", "  ");  sents[i] = sents[i].replace(" jr ", "  ");  sents[i] = sents[i].replace(" mr ", " dr ");  sents[i] = sents[i].replace(" mrs ", " dr ");  sents[i] = sents[i].replace(" sir ", " dr ");  sents[i] = sents[i].replace(" st ", " dr ");  sents[i] = sents[i].replace(" ah ", "  ");  sents[i] = sents[i].replace(" anneounced ", " announced ");  sents[i] = sents[i].replace(" anti-", " anti");  sents[i] = sents[i].replace(" co ", " cooperation ");  sents[i] = sents[i].replace(" damn it ", " damnit ");  sents[i] = sents[i].replace(" damn war ", " war ");  sents[i] = sents[i].replace(" good bye ", " goodbye ");  sents[i] = sents[i].replace(" hey ", " hi ");  sents[i] = sents[i].replace(" o ", " of ");  sents[i] = sents[i].replace(" oh ", "  ");  sents[i] = sents[i].replace(" re-", " re");  sents[i] = sents[i].replace(" san ", " san");   sents[i] = sents[i].replace(" sperm whale", " whale");
    sents[i] = sents[i].replace(" aint ", " are not ");  sents[i] = sents[i].replace(" aj ", "  ");  sents[i] = sents[i].replace(" ann ", " anne ");   sents[i] = sents[i].replace(" ay ", " yes ");  sents[i] = sents[i].replace(" aye ", " yes ");  sents[i] = sents[i].replace(" by the bye ", "  ");  sents[i] = sents[i].replace(" couldnt ", " could not ");  sents[i] = sents[i].replace(" damndue to ", " because of ");  sents[i] = sents[i].replace(" dont ", " do not ");  sents[i] = sents[i].replace(" em  ", " them ");  sents[i] = sents[i].replace(" ere ", " before ");  sents[i] = sents[i].replace(" hitherto ", " until now ");  sents[i] = sents[i].replace(" nay ", " no "); sents[i] = sents[i].replace(" nigh ", " near ");  sents[i] = sents[i].replace(" re ", " about ");   sents[i] = sents[i].replace(" till ", " until ");  sents[i] = sents[i].replace(" tis ", " it is ");  sents[i] = sents[i].replace(" whats ", " what is ");  sents[i] = sents[i].replace(" ye ", " you ");  sents[i] = sents[i].replace(" yes aye ", "  ");  sents[i] = sents[i].replace(" your majesty ", " you ");  sents[i] = sents[i].replace(" thou canst ", " you can ");  sents[i] = sents[i].replace(" thou hast ", " you have ");  sents[i] = sents[i].replace(" thee ", " you ");  sents[i] = sents[i].replace(" thou ", " you ");  sents[i] = sents[i].replace(" thoust ", " you have ");  sents[i] = sents[i].replace(" thy ", " your ");
    sents[i] = sents[i].replace(" hed be ", " he would be ");  sents[i] = sents[i].replace(" hed been ", " he had been ");  sents[i] = sents[i].replace(" hed come ", " he would come ");  sents[i] = sents[i].replace(" hed creep ", " he would  creep ");  sents[i] = sents[i].replace(" hed decided ", " he had decided ");  sents[i] = sents[i].replace(" hed do ", " he would  do ");  sents[i] = sents[i].replace(" hed give ", " he would give ");  sents[i] = sents[i].replace(" hed got ", " he had got ");  sents[i] = sents[i].replace(" hed had ", " he had had ");  sents[i] = sents[i].replace(" hed have ", " he would have ");  sents[i] = sents[i].replace(" hed leave ", " he would leave ");  sents[i] = sents[i].replace(" hed left ", " he had left ");  sents[i] = sents[i].replace(" hed meet ", " he would meet ");  sents[i] = sents[i].replace(" hed not care ", " he would not care ");  sents[i] = sents[i].replace(" hed take ", " he would take ");  sents[i] = sents[i].replace(" hed tell ", " he would tell ");  sents[i] = sents[i].replace(" hed told ", " he had told ");  sents[i] = sents[i].replace(" youd decided ", " you had decided ");  sents[i] = sents[i].replace(" youd learned ", " you had learned ");  sents[i] = sents[i].replace(" youd missed ", " you had missed ");
    sents[i] = sents[i].replace(" abra ", " smith ");  sents[i] = sents[i].replace(" ada ", " johnson ");  sents[i] = sents[i].replace(" adams ", " smith ");  sents[i] = sents[i].replace(" baker ", " smith ");  sents[i] = sents[i].replace(" barton ", " smith ");  sents[i] = sents[i].replace(" batess ", " williams ");  sents[i] = sents[i].replace(" benwick ", " williams ");  sents[i] = sents[i].replace(" bildad ", " smith ");  sents[i] = sents[i].replace(" burke ", " williams ");  sents[i] = sents[i].replace(" bursal ", " williams ");  sents[i] = sents[i].replace(" captain harville ", " johnson ");  sents[i] = sents[i].replace(" captain wentworth ", " johnson ");  sents[i] = sents[i].replace(" carlo ", " johnson ");  sents[i] = sents[i].replace(" celies ", " johnson ");  sents[i] = sents[i].replace(" clayton ", " williams ");  sents[i] = sents[i].replace(" dashwood ", " smith ");  sents[i] = sents[i].replace(" dashwoods ", " johnson ");  sents[i] = sents[i].replace(" donwell ", " williams ");  sents[i] = sents[i].replace(" doyle ", " williams ");  sents[i] = sents[i].replace(" edwards ", " williams ");  sents[i] = sents[i].replace(" eltons ", " smith ");  sents[i] = sents[i].replace(" estherson ", " johnson ");  sents[i] = sents[i].replace(" fairfax ", " williams ");  sents[i] = sents[i].replace(" felix ", " williams ");  sents[i] = sents[i].replace(" frederick ", " johnson ");  sents[i] = sents[i].replace(" garland ", " smith ");  sents[i] = sents[i].replace(" gresham ", " johnson ");  sents[i] = sents[i].replace(" grey ", " williams ");  sents[i] = sents[i].replace(" hardwick ", " smith ");  sents[i] = sents[i].replace(" hartfield ", " johnson ");  sents[i] = sents[i].replace(" jennings ", " smith ");  sents[i] = sents[i].replace(" jones ", " smith ");  sents[i] = sents[i].replace(" joseph ", " smith ");  sents[i] = sents[i].replace(" kennedy ", " johnson ");  sents[i] = sents[i].replace(" kiz ", " smith ");  sents[i] = sents[i].replace(" kizzie ", " johnson ");  sents[i] = sents[i].replace(" knightley ", " johnson ");  sents[i] = sents[i].replace(" langford ", " williams ");  sents[i] = sents[i].replace(" lee ", " smith ");  sents[i] = sents[i].replace(" lewis ", " smith ");  sents[i] = sents[i].replace(" loveit ", " williams ");  sents[i] = sents[i].replace(" martin ", " williams ");  sents[i] = sents[i].replace(" maude ", " smith ");  sents[i] = sents[i].replace(" middleton ", " smith ");  sents[i] = sents[i].replace(" miss johnson ", " dr johnson ");  sents[i] = sents[i].replace(" miss smith ", " dr smith ");  sents[i] = sents[i].replace(" miss williams ", " dr williams ");  sents[i] = sents[i].replace(" morgan ", " johnson ");  sents[i] = sents[i].replace(" murphy ", " johnson ");  sents[i] = sents[i].replace(" musgrove ", " williams ");  sents[i] = sents[i].replace(" musgroves ", " williams ");  sents[i] = sents[i].replace(" norland ", " williams ");  sents[i] = sents[i].replace(" palmer ", " johnson ");  sents[i] = sents[i].replace(" peleg ", " johnson ");  sents[i] = sents[i].replace(" piedro ", " smith ");  sents[i] = sents[i].replace(" pulova ", " smith ");  sents[i] = sents[i].replace(" queequeg ", " williams ");  sents[i] = sents[i].replace(" roberts ", " johnson ");  sents[i] = sents[i].replace(" rossoff ", " williams ");  sents[i] = sents[i].replace(" russell ", " johnson ");  sents[i] = sents[i].replace(" schwarzkopf ", " johnson ");  sents[i] = sents[i].replace(" shirley ", " williams ");  sents[i] = sents[i].replace(" stuart ", " johnson ");  sents[i] = sents[i].replace(" sutherland ", " williams ");  sents[i] = sents[i].replace(" talbot ", " williams ");  sents[i] = sents[i].replace(" tamiris ", " smith ");  sents[i] = sents[i].replace(" tarlton ", " johnson ");  sents[i] = sents[i].replace(" taylor ", " smith ");  sents[i] = sents[i].replace(" vaughan ", " johnson ");  sents[i] = sents[i].replace(" vieth ", " williams ");  sents[i] = sents[i].replace(" walter ", " williams ");  sents[i] = sents[i].replace(" watson ", " johnson ");  sents[i] = sents[i].replace(" wentworth ", " williams ");  sents[i] = sents[i].replace(" weston ", " smith ");  sents[i] = sents[i].replace(" westons ", " smiths ");  sents[i] = sents[i].replace(" wheeler ", " smith ");  sents[i] = sents[i].replace(" willoughby ", " johnson ");  sents[i] = sents[i].replace(" wilson ", " williams ");  sents[i] = sents[i].replace(" winston ", " williams ");  sents[i] = sents[i].replace(" woodhouse ", " smith ");  sents[i] = sents[i].replace(" xydis ", " johnson ");
    sents[i] = sents[i].replace(" annee ", " jane ");  sents[i] = sents[i].replace(" annees ", " janes ");  sents[i] = sents[i].replace(" barbara ", " jane ");  sents[i] = sents[i].replace(" bates ", " emma ");  sents[i] = sents[i].replace(" betsy ", " alice ");  sents[i] = sents[i].replace(" cecilia ", " alice ");  sents[i] = sents[i].replace(" eileen ", " emma ");  sents[i] = sents[i].replace(" elinor ", " jane ");  sents[i] = sents[i].replace(" elinors ", " janes ");  sents[i] = sents[i].replace(" folly ", " emma ");  sents[i] = sents[i].replace(" glenda ", " alice ");  sents[i] = sents[i].replace(" harriet ", " jane ");  sents[i] = sents[i].replace(" harriets ", " janes ");  sents[i] = sents[i].replace(" henrietta ", " jane ");  sents[i] = sents[i].replace(" isabella ", " emma ");  sents[i] = sents[i].replace(" jen ", " jane ");  sents[i] = sents[i].replace(" joan ", " alice ");  sents[i] = sents[i].replace(" julia ", " emma ");  sents[i] = sents[i].replace(" kate ", " jane ");  sents[i] = sents[i].replace(" katherine ", " alice ");  sents[i] = sents[i].replace(" laura ", " emma ");  sents[i] = sents[i].replace(" leonora ", " alice ");  sents[i] = sents[i].replace(" linda ", " jane ");  sents[i] = sents[i].replace(" louisa ", " jane ");  sents[i] = sents[i].replace(" margaret ", " alice ");  sents[i] = sents[i].replace(" mariannee ", " alice ");  sents[i] = sents[i].replace(" mariannee ", " jane ");  sents[i] = sents[i].replace(" mariannees ", " janes ");  sents[i] = sents[i].replace(" mary ", " jane ");  sents[i] = sents[i].replace(" miss alice ", " dr alice ");  sents[i] = sents[i].replace(" miss emma ", " dr emma ");  sents[i] = sents[i].replace(" miss jane ", " dr jane ");  sents[i] = sents[i].replace(" rachel ", " alice ");  sents[i] = sents[i].replace(" rosamond ", " alice ");  sents[i] = sents[i].replace(" sophy ", " alice ");  sents[i] = sents[i].replace(" susan ", " emma ");  sents[i] = sents[i].replace(" susans ", " emmas ");  sents[i] = sents[i].replace(" theresa ", " emma ");
    sents[i] = sents[i].replace(" ahab ", " elliot ");  sents[i] = sents[i].replace(" ahabs ", " elliots ");  sents[i] = sents[i].replace(" ahalexander ", " elton ");  sents[i] = sents[i].replace(" ahtom ", " elliot ");  sents[i] = sents[i].replace(" alfred ", " elliot ");  sents[i] = sents[i].replace(" bildad ", " elton ");  sents[i] = sents[i].replace(" billy ", " edward ");  sents[i] = sents[i].replace(" captain benwick ", " edward ");  sents[i] = sents[i].replace(" captain bildad ", " elton ");  sents[i] = sents[i].replace(" captain peleg ", " elliot ");  sents[i] = sents[i].replace(" charles ", " elton ");  sents[i] = sents[i].replace(" charlie ", " elton ");  sents[i] = sents[i].replace(" churchill ", " elliot ");  sents[i] = sents[i].replace(" david ", " elton ");  sents[i] = sents[i].replace(" francisco ", " edward ");  sents[i] = sents[i].replace(" franklin ", " edward ");  sents[i] = sents[i].replace(" george ", " elton ");  sents[i] = sents[i].replace(" hal ", " elton ");  sents[i] = sents[i].replace(" hans ", " elliot ");  sents[i] = sents[i].replace(" hartfield ", " smith ");  sents[i] = sents[i].replace(" jack ", " edward ");  sents[i] = sents[i].replace(" james ", " edward ");  sents[i] = sents[i].replace(" jem ", " elliot ");  sents[i] = sents[i].replace(" jonah ", " elliot ");  sents[i] = sents[i].replace(" lawrence ", " elton ");  sents[i] = sents[i].replace(" louis ", " edward ");  sents[i] = sents[i].replace(" mike ", " elton ");  sents[i] = sents[i].replace(" nayopeleg ", " elliot ");  sents[i] = sents[i].replace(" paul ", " edward ");  sents[i] = sents[i].replace(" perry ", " elton ");  sents[i] = sents[i].replace(" peter ", " eliot ");  sents[i] = sents[i].replace(" phil ", " elliot ");  sents[i] = sents[i].replace(" philip ", " edward ");  sents[i] = sents[i].replace(" richard ", " elton ");  sents[i] = sents[i].replace(" robert ", " elliot ");  sents[i] = sents[i].replace(" sam ", " edward ");  sents[i] = sents[i].replace(" sammy ", " edward ");  sents[i] = sents[i].replace(" starbuck ", " elton ");  sents[i] = sents[i].replace(" tashtego ", " elliot ");  sents[i] = sents[i].replace(" the hatter ", " eliot ");  sents[i] = sents[i].replace(" the tailor ", " elton ");  sents[i] = sents[i].replace(" thomas ", " elliot ");  sents[i] = sents[i].replace("  ", " ");
    sents[i] = sents[i].replace(" brahmin ", " man ");  sents[i] = sents[i].replace(" britain ", " england ");  sents[i] = sents[i].replace(" british ", " english ");  sents[i] = sents[i].replace(" dormouse ", " mouse ");  sents[i] = sents[i].replace(" gingerbread boy ", " gingerbreadboy ");  sents[i] = sents[i].replace(" guinea-", "guinea");  sents[i] = sents[i].replace(" guinea pig ", " guineapig ");  sents[i] = sents[i].replace(" guineahatter ", " man ");  sents[i] = sents[i].replace(" harpooneer ", " man ");  sents[i] = sents[i].replace(" harpooneers ", " men ");  sents[i] = sents[i].replace(" highbury ", " paris ");  sents[i] = sents[i].replace(" leviathan ", " monster ");  sents[i] = sents[i].replace(" little fir tree ", " little tree ");  sents[i] = sents[i].replace(" look-outs ", " lookouts ");  sents[i] = sents[i].replace(" maam ", " madam ");  sents[i] = sents[i].replace(" mamma ", " mother ");  sents[i] = sents[i].replace(" mast-heads ", " mastheads ");  sents[i] = sents[i].replace(" moby dick ", " the whale ");  sents[i] = sents[i].replace(" morrow ", " tomorrow ");  sents[i] = sents[i].replace(" new guinea ", " newguinea ");  sents[i] = sents[i].replace(" papa ", " father ");  sents[i] = sents[i].replace(" pequods ", " ships ");  sents[i] = sents[i].replace(" pequods boats ", " ships ");  sents[i] = sents[i].replace(" randalls ", " paris ");  sents[i] = sents[i].replace(" san francisco ", " sanfrancisco ");  sents[i] = sents[i].replace(" seamen ", " men ");  sents[i] = sents[i].replace(" soviet union ", " soviet ");  sents[i] = sents[i].replace(" the guinea ", " the dollar ");  sents[i] = sents[i].replace(" the pequod ", " the ship ");  sents[i] = sents[i].replace(" whaleman ", " man ");  sents[i] = sents[i].replace(" whalemen ", " men ");  sents[i] = sents[i].replace(" young gentleman ", " young man ");

# %%
#### removing chapter header ###
for i in range(len(sents)):
     if (type(sents[i]) != str):  continue
     if sents[i][:8].find('chapter') != -1:  sents[i] = "";
     elif sents[i].find(') chapter ') != -1:  sents[i] = "";
     elif sents[i][:6].find('page ') != -1:  sents[i] = "";
     elif sents[i].find('[illustration') != -1:  sents[i] = "";

# %%
#### removing afer (" said), (e.g. "I will do" said alice.) ###
for i in range(len(sents)):
     if (type(sents[i]) != str):  continue
     if sents[i].find('" said ') != -1:  sents[i] = sents[i][:sents[i].find('" said ')];
     # if sents[i].find('" answered ') != -1:  sents[i] = sents[i][:sents[i].find('" answered ')];

# %%
#### removing French sentences ###
for i in range(len(sents)):
     if (type(sents[i]) != str):  continue
     if sents[i].find(' la ') != -1:  sents[i] = "";
     elif sents[i].find(' non ') != -1:  sents[i] = "";

# %%
#### removing sentences contains hi gentlemen/gentleman sir damn or af ###
for i in range(len(sents)):
     if (type(sents[i]) != str):  continue
     if sents[i].find(' hi ') != -1:  sents[i] = "";  ## <40 sentences
     elif sents[i].find(' gentlemen ') != -1:  sents[i] = "";
     elif sents[i].find(' a d 0 ') != -1:  sents[i] = "";
     elif sents[i].find(' af ') != -1:  sents[i] = "";
     elif sents[i][:6].find('said ') != -1:  sents[i] = "";
    #  elif sents[i].find(' damn ') != -1:  sents[i] = "";

# %%
##### preprocessing: tokenizing #####
num_words = 3000
tokenizer = preprocessing.text.Tokenizer(oov_token='unk')
tokenizer.fit_on_texts(sents)
tokenizer.word_index = {e:i for e,i in tokenizer.word_index.items() if i <= num_words} ####
tokenizer.word_index[tokenizer.oov_token] = num_words + 1 #### These two lines are necessary to remove rare words
w_idx = tokenizer.word_index
w_idx['_'] = 0;   w_idx['unk'] = 1;
idx_to_word = dict([(value, key) for (key, value) in w_idx.items()])

# %%
print(w_idx)
# Out:
# {'unk': 1, 'the': 2, 'and': 3, 'of': 4, 'to': 5, 'a': 6, 'in': 7, 'was': 8, 'i': 9, 'he': 10, 'it': 11, 'that': 12, 'not': 13, 'his': 14, 'for': 15, 'you': 16, 'is': 17, 'as': 18, 'her': 19, 'with': 20, 'had': 21, 'be': 22, 'she': 23, 'but': 24, 'at': 25, 'on': 26, 'have': 27, 'dr': 28, 'all': 29, 'this': 30, 'him': 31, 'by': 32, 'they': 33, 'from': 34, 'so': 35, 'would': 36, 'were': 37, 'one': 38, 'which': 39, 'no': 40, 'will': 41, 'there': 42, 'are': 43, 'or': 44, 'my': 45, 'could': 46, 'do': 47, 'an': 48, 'what': 49, 'been': 50, 'when': 51, 'zero': 52, 'me': 53, 'their': 54, 'them': 55, 'very': 56, 'if': 57, 'more': 58, 'out': 59, 'who': 60, 'up': 61, 'said': 62, 'we': 63, 'now': 64, 'can': 65, 'little': 66, 'did': 67, 'your': 68, 'than': 69, 'then': 70, 'any': 71, 'some': 72, 'into': 73, 'time': 74, 'about': 75, 'only': 76, 'like': 77, 'has': 78, 'man': 79, 'such': 80, 'must': 81, 'much': 82, 'well': 83, 'other': 84, 'smith': 85, 'good': 86, 'how': 87, 'before': 88, 'know': 89, 'jane': 90, 'am': 91, 'two': 92, 'over': 93, 'never': 94, 'see': 95, 'its': 96, 'down': 97, 'first': 98, 'after': 99, 'should': 100, 'own': 101, 'johnson': 102, 'williams': 103, 'upon': 104, 'great': 105, 'every': 106, 'too': 107, 'made': 108, 'most': 109, 'old': 110, 'these': 111, 'being': 112, 'here': 113, 'might': 114, 'way': 115, 'think': 116, 'long': 117, 'may': 118, 'just': 119, 'say': 120, 'day': 121, 'again': 122, 'go': 123, 'elliot': 124, 'even': 125, 'back': 126, 'come': 127, 'came': 128, 'make': 129, 'emma': 130, 'thought': 131, 'elton': 132, 'though': 133, 'where': 134, 'last': 135, 'himself': 136, 'thing': 137, 'still': 138, 'new': 139, 'off': 140, 'without': 141, 'our': 142, 'nothing': 143, 'many': 144, 'us': 145, 'whale': 146, 'those': 147, 'away': 148, 'ever': 149, 'through': 150, 'while': 151, 'men': 152, 'house': 153, 'get': 154, 'take': 155, 'went': 156, 'always': 157, 'head': 158, 'same': 159, 'look': 160, 'yet': 161, 'saw': 162, 'until': 163, 'sure': 164, 'because': 165, 'herself': 166, 'seemed': 167, 'another': 168, 'give': 169, 'three': 170, 'edward': 171, 'soon': 172, 'right': 173, 'home': 174, 'years': 175, 'life': 176, 'once': 177, 'something': 178, 'people': 179, 'world': 180, 'found': 181, 'place': 182, 'quite': 183, 'shall': 184, 'young': 185, 'looked': 186, 'going': 187, 'enough': 188, 'better': 189, 'heard': 190, 'let': 191, 'father': 192, 'mother': 193, 'hand': 194, 'however': 195, 'eyes': 196, 'tell': 197, 'few': 198, 'why': 199, 'room': 200, 'left': 201, 'both': 202, 'half': 203, 'almost': 204, 'knew': 205, 'each': 206, 'got': 207, 'work': 208, 'felt': 209, 'night': 210, 'under': 211, 'put': 212, 'mind': 213, 'does': 214, 'yes': 215, 'side': 216, 'done': 217, 'against': 218, 'alice': 219, 'told': 220, 'also': 221, 'between': 222, 'took': 223, 'white': 224, 'indeed': 225, 'moment': 226, 'far': 227, 'morning': 228, 'things': 229, 'cried': 230, 'door': 231, 'part': 232, 'seen': 233, 'dear': 234, 'rather': 235, 'since': 236, 'poor': 237, 'next': 238, 'perhaps': 239, 'find': 240, 'called': 241, 'having': 242, 'water': 243, 'began': 244, 'want': 245, 'lady': 246, 'whole': 247, 'ship': 248, 'set': 249, 'sea': 250, 'face': 251, 'year': 252, 'round': 253, 'boy': 254, 'small': 255, 'best': 256, 'really': 257, 'friend': 258, 'around': 259, 'end': 260, 'present': 261, 'hear': 262, 'gave': 263, 'woman': 264, 'high': 265, 'days': 266, 'together': 267, 'nor': 268, 'asked': 269, 'anne': 270, 'body': 271, 'heart': 272, 'love': 273, 'word': 274, 'course': 275, 'turned': 276, 'hope': 277, 'hands': 278, 'captain': 279, 'often': 280, 'kind': 281, 'least': 282, 'john': 283, 'among': 284, 'myself': 285, 'voice': 286, 'marianne': 287, 'wish': 288, 'others': 289, 'four': 290, 'family': 291, 'less': 292, 'full': 293, 'anything': 294, 'used': 295, 'name': 296, 'sort': 297, 'looking': 298, 'open': 299, 'along': 300, 'believe': 301, 'children': 302, 'gone': 303, 'near': 304, 'happy': 305, 'given': 306, 'state': 307, 'use': 308, 'feel': 309, 'ai ...

# %%
len(w_idx)
# Out:
# 3001

# %%
sents = tokenizer.texts_to_sequences(sents);

# %%
seq_length = 2 * time_step;
sents = preprocessing.sequence.pad_sequences(sents, maxlen=seq_length-time_step+1, padding='pre', truncating='post')
sents = np.concatenate( (np.zeros((np.size(sents,0),time_step-1)),sents), axis=1)

# %%
sents_0 = sents
np.shape(sents_0)
# Out:
# (88708, 32)

# %%
sents = sents[np.sum(sents>0,axis=1)>2,:]  # removing too short sentences

# %%
sents = sents[np.sum(sents[:,0:time_step+12]==w_idx['unk'],axis=1)<4,:]  # excluding too many unk

# %%
np.shape(sents)
# Out:
# (79442, 32)

# %%
##### shuffling sentenses #####
sents = np.random.permutation(sents);         sent_2 = sents +0;

# %%
##### preparing training dataset #####
batch_size = 64;

# %%
##### training data and validation data #######
train_val_rate = 0.90; # 90% for training, 10% for validation
train_start = 0;                train_end = round(len(sents) * train_val_rate)
val_start = train_end + 1;      val_end = len(sents);

# %%
def sample_generator(start, end):
    # while True:
    for ep in range(10000):
        start0 = start + (ep%2)*(batch_size//2);  end0 = end - batch_size + (ep%2)*(batch_size//2);
        if ep%2 == 0 and start<train_end:     sent_2[train_start:train_end,:] = np.random.permutation(sent_2[train_start:train_end,:])
        elif ep> 0 and start>train_end:       sent_2[val_start:val_end,:] = np.random.permutation(sent_2[val_start:val_end,:])
        for step in range((end0 - start0) // batch_size):
            x, y = [],[]
            for line in range(batch_size):
                dataset = preprocessing.sequence.TimeseriesGenerator(
                    sent_2[start0+step*batch_size+line],
                    sent_2[start0+step*batch_size+line],  length=time_step,   batch_size=1)
                for batch in dataset:
                    X, Y = batch;      x.extend(X[0]);     y.extend(Y);
            x = np.reshape(x,((seq_length-time_step)*batch_size,time_step))
            y = keras.utils.to_categorical(y, len(w_idx))
            # y = np.matmul(keras.utils.to_categorical(y, len(w_idx)), w2v_matrix)  # target in the embedding space
            yield x, y

# %%
val_batch_size = batch_size;

# %%
def sample_generator_evaluation(start, end):
    for step in range((end - start) // val_batch_size):
        x, y = [],[]
        for line in range(val_batch_size):
            dataset = preprocessing.sequence.TimeseriesGenerator(
                sents[start+step*val_batch_size+line],   sents[start+step*val_batch_size+line],  length=time_step,   batch_size=1)
            for batch in dataset:     X, Y = batch;   x.extend(X[0]);   y.extend(Y);
        x = np.reshape(x,((seq_length-time_step)*val_batch_size,time_step))
        y = keras.utils.to_categorical(y, len(w_idx))
        yield x, y

# %%
###################### Buliding ANN Model #####################################################

# %%
dp_rate = 0.0; dp_through_rate = 0.0;
gr_scale = 1;   min_fb_gr_b = - 0.5;  max_fb_gr_b = 0.0;
p_cell = 192;
leaky_relu = 0.02;      sqrt_leak = 1; # (0 or 1) sqrt_leak should be 1, if gr_scale > 1
p_relu_on = 0; p_relu = 0.0;

# %%
if leaky_relu > 0 and sqrt_leak == 1:         leaky_relu_in = np.sqrt(leaky_relu);    leaky_relu_pc = np.sqrt(leaky_relu);
elif leaky_relu > 0:                          leaky_relu_in = 1.0;                    leaky_relu_pc = leaky_relu;
elif leaky_relu == 0 and p_relu_on == 1:      leaky_relu_in = 1.0;                    leaky_relu_pc = 0.0; # dummy (p-relu for pc),
else:                                         leaky_relu_in = 0.0;                    leaky_relu_pc = 0.0; # ReLU in PC and input cells,  ## when leaky_relu == 0 and p_relu_on == 0:
leaky_relu_out = 1.0;

# %%
ind_pos = max_fb_gr_b // ((max_fb_gr_b-min_fb_gr_b) /gr_scale);
cANN_DM = 0;

# %%
class custom_RNNCell(layers.AbstractRNNCell):
    def __init__(self, units,  **kwargs):
        super(custom_RNNCell, self).__init__(**kwargs)
        self.units = units
        self.prelu = tf.keras.layers.PReLU(alpha_initializer=tf.initializers.constant(p_relu))

    @property
    def state_size(self):
        return self.units

    def build(self, input_shape):
        self.w_ff = self.add_weight( shape=(input_shape[-1], self.units),
            initializer='he_normal',     name='kernel') # glorot_uniform, he_normal, orthogonal,
        self.w_pc2out = self.add_weight( shape=(self.units, self.units),
            initializer='identity', trainable=False,    name='recurrent_w0')
        self.w_out2in = self.add_weight( shape=(self.units, self.units * gr_scale),
            initializer='identity', trainable=False,    name='recurrent_w1')
        self.w_out2in = tf.concat([tf.eye(self.units) for i in range(gr_scale)],1) # producing multiple copies of states in input layer
        self.b_r_in = self.add_weight( shape=(self.units * gr_scale,),
            name='recurrent_bias',  trainable=False,    initializer='zeros')   # for recurrent input cells
        self.b_r_in = tf.concat([tf.fill([self.units,], (min_fb_gr_b-max_fb_gr_b)*(i-ind_pos)/gr_scale) for i in range(gr_scale)],0) # multiple bias values for different gr populations
        self.w_in2pc = self.add_weight( shape=(self.units * gr_scale, self.units),
            initializer='he_normal',    trainable=True, name='recurrent_w2') #  # recurrent kernel
        self.bias = self.add_weight( shape=(self.units,),
            name='bias',     initializer='zeros')  # 'glorot_normal', 'zeros', 'he_normal'
        self.built = True

    def call(self, inputs, states):
        # === recurrent activity (pc -> input cells) ======
        act_pc = states[0]
        act_out = tf.matmul(act_pc, self.w_pc2out)
        act_out = tf.nn.leaky_relu(act_pc, alpha = leaky_relu_out)
        act_in = tf.matmul(act_out, self.w_out2in)
        act_in = act_in + self.b_r_in
        act_in = tf.nn.leaky_relu(act_in, alpha = leaky_relu_in)
        # ==== PC activity ====
        h = tf.matmul(inputs, self.w_ff);
        h = h + self.bias;
        pc = h + tf.matmul(act_in, self.w_in2pc);
        if leaky_relu == 0 and p_relu_on == 1:          pc = self.prelu(pc)
        else:                                           pc = tf.nn.leaky_relu(pc, alpha = leaky_relu_pc)
        return pc, pc

# %%
##### building the model ######
def seq2vec_model_builder(HIDDEN_DIM):
    ##### input and embedding (one-hot) ######
    encoder_inputs = layers.Input(shape=(time_step, ), dtype='int32',)
    encoder_embedding = layers.Embedding(len(w_idx), len(w_idx), embeddings_initializer='identity', mask_zero=True, trainable=False)(encoder_inputs)
    ##### RNN ##########
    c_cell = custom_RNNCell( HIDDEN_DIM )
    c_cell.initial_state = tf.zeros((1, HIDDEN_DIM), tf.float32)
    encoder_RNN = layers.RNN(c_cell, return_state=True,  name='sRNN')
    encoder_outputs, state_h = encoder_RNN(encoder_embedding)
    ##### output (dense) layer ##########
    dense_layer = layers.Dense(len(w_idx),
                     bias_initializer=keras.initializers.RandomNormal(stddev=0.00001), activation='linear', kernel_constraint=keras.constraints.NonNeg(), name='dense_1')
    outputs = dense_layer(encoder_outputs)
    act_layer = tf.keras.layers.Activation('softmax')
    outputs = act_layer( - outputs)
    model = keras.Model(encoder_inputs, outputs)
    return model
model = seq2vec_model_builder(HIDDEN_DIM = p_cell)

# %%
inter_output_model = keras.Model(model.input, model.get_layer('sRNN').output )

# %%
model.get_layer('sRNN')

# %%
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 16)]              0
#
#  embedding_1 (Embedding)     (None, 16, 3001)          9006001
#
#  sRNN (RNN)                  [(None, 192),             650112
#                               (None, 192)]
#
#  dense_1 (Dense)             (None, 3001)              579193
#
#  tf.math.negative (TFOpLambd  (None, 3001)             0
#  a)
#
#  activation_1 (Activation)   (None, 3001)              0
#
# =================================================================
# Total params: 10,235,306
# Trainable params: 1,192,441
# Non-trainable params: 9,042,865
# _________________________________________________________________

# %%
increments = 32   ## split epoch (Equivalent to learning the whole sentence once) into XX

# %%
def my_loss(y_true, y_pred):
    row_wise_sum  = tf.reduce_sum(tf.gather(y_true,  [0,1], axis = 1),axis=1)
    valid = tf.reshape(tf.where(tf.equal(row_wise_sum,0)), [-1])
    loss_fn = tf.keras.losses.CategoricalCrossentropy()
    return loss_fn(y_true=tf.gather(y_true,  valid, axis = 0),  y_pred=tf.gather(y_pred,  valid, axis = 0))

# %%
def my_top_k_acc(y_true, y_pred):
    row_wise_sum  = tf.reduce_sum(tf.gather(y_true,  [0,1], axis = 1),axis=1)
    valid = tf.where(tf.equal(row_wise_sum,0))     # removing y_true = 0 or 'unk'
    values, y_ind = tf.nn.top_k(y_true, 1);    values, top_k_pred = tf.nn.top_k(y_pred, 5);
    to_top5 = tf.constant( [[ 1, 1, 1, 1, 1]] , dtype=tf.int32 )
    input_y_for_top5 = tf.matmul( tf.reshape(y_ind,[-1, 1]) , to_top5 )
    correct_preds = tf.cast( tf.equal( input_y_for_top5 , top_k_pred ) , dtype=tf.float16)
    suc_pred = tf.reduce_sum(correct_preds, axis=1);
    return tf.reduce_mean( tf.gather(suc_pred,  tf.squeeze(valid), axis = 0) )

# %%
#### optimizer ######
optimizer = keras.optimizers.Adam(learning_rate=0.0064, clipnorm=8.0) # Adam, Adadelta, RMSprop, Adagrad,
model.compile(loss=my_loss, optimizer=optimizer, run_eagerly=True, metrics=['categorical_crossentropy', my_top_k_acc])

# %%
EarlyStopping = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=increments*10, mode='auto')
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.84, patience=increments//4, min_lr=0.00002)  # faster reduce

# %%
h1 = model.evaluate(sample_generator_evaluation(train_start, train_start+(train_end - train_start) //increments))
# Out:
# 34/34 [==============================] - 4s 107ms/step - loss: 8.0079 - categorical_crossentropy: 8.0096 - my_top_k_acc: 0.0022

# %%
h2 = model.evaluate(sample_generator_evaluation(val_start, val_start+(val_end - val_start)//2) )
# Out:
# 62/62 [==============================] - 6s 102ms/step - loss: 8.0081 - categorical_crossentropy: 8.0098 - my_top_k_acc: 0.0026

# %%
##### training the model #######
history_callback = model.fit(
    sample_generator(train_start, train_end),
    steps_per_epoch=(train_end - train_start) //increments // batch_size,  # if //80, it comes full circle in increments of 80.
    validation_data=sample_generator(val_start, val_end),
    validation_steps=(val_end - val_start) // batch_size //4,
    initial_epoch=0,
    epochs=increments*8,
    # epochs=4,
    verbose=1,
    callbacks=[ EarlyStopping, reduce_lr] )
# Out:
# Epoch 1/256
# WARNING:tensorflow:5 out of the last 755 calls to <function _BaseOptimizer._update_step_xla at 0x7f4e2a679700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 34/34 [==============================] - 13s 336ms/step - loss: 7.0935 - categorical_crossentropy: 7.7419 - my_top_k_acc: 0.1445 - val_loss: 6.4730 - val_categorical_crossentropy: 7.2980 - val_my_top_k_acc: 0.1697 - lr: 0.0064
# Epoch 2/256
# 34/34 [==============================] - 10s 282ms/step - loss: 6.3485 - categorical_crossentropy: 7.2628 - my_top_k_acc: 0.1767 - val_loss: 6.2407 - val_categorical_crossentropy: 7.2437 - val_my_top_k_acc: 0.1862 - lr: 0.0064
# Epoch 3/256
# 34/34 [==============================] - 9s 278ms/step - loss: 6.1908 - categorical_crossentropy: 7.2050 - my_top_k_acc: 0.1887 - val_loss: 6.1323 - val_categorical_crossentropy: 7.1418 - val_my_top_k_acc: 0.1872 - lr: 0.0064
# Epoch 4/256
# 34/34 [==============================] - 11s 327ms/step - loss: 6.0737 - categorical_crossentropy: 7.1511 - my_top_k_acc: 0.1946 - val_loss: 6.0631 - val_categorical_crossentropy: 7.2246 - val_my_top_k_acc: 0.2011 - lr: 0.0064
# Epoch 5/256
# 34/34 [==============================] - 10s 290ms/step - loss: 5.9549 - categorical_crossentropy: 7.1055 - my_top_k_acc: 0.2109 - val_loss: 5.9197 - val_categorical_crossentropy: 7.1239 - val_my_top_k_acc: 0.2168 - lr: 0.0064
# Epoch 6/256
# 34/34 [==============================] - 12s 342ms/step - loss: 5.8388 - categorical_crossentropy: 7.0722 - my_top_k_acc: 0.2265 - val_loss: 5.7703 - val_categorical_crossentropy: 7.1139 - val_my_top_k_acc: 0.2423 - lr: 0.0064
# Epoch 7/256
# 34/34 [==============================] - 12s 347ms/step - loss: 5.7427 - categorical_crossentropy: 7.0500 - my_top_k_acc: 0.2474 - val_loss: 5.6939 - val_categorical_crossentropy: 7.0623 - val_my_top_k_acc: 0.2550 - lr: 0.0064
# Epoch 8/256
# 34/34 [==============================] - 9s 281ms/step - loss: 5.6151 - categorical_crossentropy: 7.0181 - my_top_k_acc: 0.2664 - val_loss: 5.5840 - val_categorical_crossentropy: 7.0176 - val_my_top_k_acc: 0.2775 - lr: 0.0064
# Epoch 9/256
# 34/34 [==============================] - 11s 325ms/step - loss: 5.5353 - categorical_crossentropy: 6.9974 - my_top_k_acc: 0.2798 - val_loss: 5.5370 - val_categorical_crossentropy: 7.0356 - val_my_top_k_acc: 0.2824 - lr: 0.0064
# Epoch 10/256
# 34/34 [==============================] - 9s 256ms/step - loss: 5.4635 - categorical_crossentropy: 7.0095 - my_top_k_acc: 0.2940 - val_loss: 5.4552 - val_categorical_crossentropy: 7.0029 - val_my_top_k_acc: 0.2936 - lr: 0.0064
# Epoch 11/256
# 34/34 [==============================] - 12s 353ms/step - loss: 5.4040 - categorical_crossentropy: 6.9523 - my_top_k_acc: 0.2935 - val_loss: 5.3925 - val_categorical_crossentropy: 6.9681 - val_my_top_k_acc: 0.3023 - lr: 0.0064
# Epoch 12/256
# 34/34 [==============================] - 10s 305ms/step - loss: 5.3522 - categorical_crossentropy: 6.9885 - my_top_k_acc: 0.2990 - val_loss: 5.3603 - val_categorical_crossentropy: 7.0202 - val_my_top_k_acc: 0.3006 - lr: 0.0064
# Epoch 13/256
# 34/34 [==============================] - 11s 333ms/step - loss: 5.2997 - categorical_crossentropy: 6.9690 - my_top_k_acc: 0.3061 - val_loss: 5.3400 - val_categorical_crossentropy: 7.0138 - val_my_top_k_acc: 0.3071 - lr: 0.0064
# Epoch 14/256
# 34/34 [==============================] - 11s 325ms/step - loss: 5.2679 - categorical_crossentropy: 6.9469 - my_top_k_acc: 0.3123 - val_loss: 5.3136 - val_categorical_crossentropy: 7.0112 - val_my_top_k_acc: 0.3082 - lr: 0.0064
# Epoch 15/256
# 34/34 [==============================] - 9s 256ms/step - loss: 5.2672 - categorical_crossentropy: 6.9857 - my_top_k_acc: 0.3155 - val_loss: 5.2623 - val_categorical_crossentropy: 6.9891 - val_my_top_k_acc: 0.3120 - lr: 0.0064
# Epoch 16/256
# 34/34 [==============================] - 12s 348ms/step - loss: 5.2326 - categorical_crossentropy: 6.9930 - my_top_k_acc: 0.3150 - val_loss: 5.2442 - val_categorical_crossentropy: 7.0728 - val_my_top_k_acc: 0.3183 - lr: 0.0064
# Epoch 17/256
# 34/34 [==============================] - 12s 347ms/step - loss: 5.2337 - categorical_crossentropy: 7.0008 - my_top_k_acc: 0.3157 - val_loss: 5.2075 - val_categorical_crossentropy: 6.9602 - val_my_top_k_acc: 0.3229 - lr: 0.0064
# Epoch 18/256
# 34/34 [==============================] - 12s 344ms/step - loss: 5.2158 - categorical_crossentropy: 7.0250 - my_top_k_acc: 0.3177 - val_loss: 5.2021 - val_categorical_crossentropy: 7.0269 - val_my_top_k_acc: 0.3180 - lr: 0.0064
# Epoch 19/256
# 34/34 [==============================] - 10s 284ms/step - loss: 5.2020 - categorical_crossentropy: 7.0028 - my_top_k_acc: 0.3164 - val_loss: 5.1636 - val_categorical_crossentropy: 7.0177 - val_my_top_k_acc: 0.3244 - lr: 0.0064
# Epoch 20/256
# 34/34 [==============================] - 9s 275ms/step - loss: 5.1604 - categorical_crossentropy: 7.0288 - my_top_k_acc: 0.3215 - val_loss: 5.1316 - val_categorical_crossentropy: 6.9879 - val_my_top_k_acc: 0.3268 - lr: 0.0064
# Epoch 21/256
# 34/34 [==============================] - 10s 284ms/step - loss: 5.1319 - categorical_crossentropy: 7.0563 - my_top_k_acc: 0.3234 - val_loss: 5.1244 - val_categorical_crossentropy: 7.0362 - val_my_top_k_acc: 0.3289 - lr: 0.0064
# Epoch 22/256
# 34/34 [==============================] - 11s 323ms/step - loss: 5.1242 - categorical_crossentropy: 7.0626 - my_top_k_acc: 0.3273 - val_loss: 5.1435 - val_categorical_crossentropy: 7.0370 - val_my_top_k_acc: 0.3237 - lr: 0.0064
# Epoch 23/256
# 34/34 [==============================] - 9s 254ms/step - loss: 5.1213 - categorical_crossentropy: 7.0153 - my_top_k_acc: 0.3276 - val_loss: 5.1315 - val_categorical_crossentropy: 7.0791 - val_my_top_k_acc: 0.3308 - lr: 0.0064
# Epoch 24/256
# 34/34 [==============================] - 9s 276ms/step - loss: 5.0449 - categorical_crossentropy: 6.9973 - my_top_k_acc: 0.3357 - val_loss: 5.1008 - val_categorical_crossentropy: 7.0730 - val_my_top_k_acc: 0.3315 - lr: 0.0064
# Epoch 25/256
# 34/34 [==============================] - 11s 337ms/step - loss: 5.0665 - categorical_crossentropy: 7.0622 - my_top_k_acc: 0.3346 - val_loss: 5.0611 - val_categorical_crossentropy: 7.0679 - val_my_top_k_acc: 0.3332 - lr: 0.0064
# Epoch 26/256
# 34/34 [==============================] - 11s 322ms/step - loss: 5.0614 - categorical_crossentropy: 7.0478 - my_top_k_acc: 0.3343 - val_loss: 5.0457 - val_categorical_crossentropy: 7.0638 - val_my_top_k_acc: 0.3390 - lr: 0.0064
# Epoch 27/256
# 34/34 [==============================] - 12s 344ms/step - loss: 5.0606 - categorical_crossentropy: 7.0851 - my_top_k_acc: 0.3320 - val_loss: 5.0825 - val_categorical_crossentropy: 7.1397 - val_my_top_k_acc: 0.3337 - lr: 0.0064
# Epoch 28/256
# 34/34 [==============================] - 9s 255ms/step - loss: 5.0636 - categorical_crossentropy: 7.0950 - my_top_k_acc: 0.3303 - val_loss: 5.0462 - val_categorical_crossentropy: 7.1221 - val_my_top_k_acc: 0.3376 - lr: 0.0064
# Epoch 29/256
# 34/34 [==============================] - 12s 347ms/step - loss: 5.0129 - categorical_crossentropy: 7.1035 - my_top_k_acc: 0.3380 - val_loss: 5.0586 - val_categorical_crossentropy: 7.0674 - val_my_top_k_acc: 0.3308 - lr: 0.0064
# Epoch 30/256
# 34/34 [==============================] - 9s 280ms/step - loss: 5.0422 - categorical_crossentropy: 7.1035 - my_top_k_acc: 0.3351 - val_loss: 5.0135 - val_categorical_crossentropy: 7.1813 - val_my_top_k_acc: 0.3413 - lr: 0.0064
# Epoch 31/256
# 34/34 [==============================] - 11s 324ms/step - loss: 4.9700 - categorical_crossentropy: 7.0671 - my_top_k_acc: 0.3425 - val_loss: 5.0072 - val_categorical_crossentropy: 7.1341 - val_my_top_k_acc: 0.3374 - lr: 0.0064
# Epoch 32/256
# 34/34 [==============================] - 11s 325ms/step - loss: 4.9765 - categorical_crossentropy: 7.0906 - my_top_k_acc: 0.3399 - val_loss: 5.0203 - val_categorical_crossentropy: 7.1584 - val_my_top_k_acc: 0.3342 - lr: 0.0064
# Epoch 33/256
# 34/34 [==============================] - 11s 323ms/step - loss: 4.9778 - categorical_crossentropy: 7.1332 - my_top_k_acc: 0.3421 - val_loss: 5.0137 - val_categorical_crossentropy: 7.1654 - val_my_top_k_acc: 0.3399 - lr: 0.0064
# Epoch 34/256
# 34/34 [==============================] - 10s 292ms/step - loss: 4.9851 - categorical_crossentropy: 7.1190 - my_top_k_acc: 0.3400 - val_loss: 5.0016 - val_categorical_crossentropy: 7.1874 - val_my_top_k_acc: 0.3423 - lr: 0.0064
# Epoch 35/256
# 34/34 [==============================] - 12s 350ms/step - loss: 4.9858 - categorical_crossentropy: 7.2206 - my_top_k_acc: 0.3392 - val_loss: 4.9940 - val_categorical_crossentropy: 7.1546 - val_my_top_k_acc: 0.3378 - lr: 0.0064
# Epoch 36/256
# 34/34 [==============================] - 12s 346ms/step - loss: 4.9860 - categorical_crossentropy: 7.1889 - my_top_k_acc: 0.3383 - val_loss: 4.9656 - val_categorical_crossentropy: 7.1092 - val_my_top_k_acc: 0.3405 - lr: 0.0064
# Epoch 37/256
# 34/34 [==============================] - 11s 335ms/step - loss: 4.9304 - categorical_crossentropy: 7.1410 - my_top_k_acc: 0.3454 - val_loss: 4.9776 - val_categorical_crossentropy: 7.2405 - val_my_top_k_acc: 0.3424 - lr: 0.0064
# Epoch 38/256
# 34/34 [==============================] - 11s 325ms/step - loss: 4.9224 - categorical_crossentropy: 7.1566 - my_top_k_acc: 0.3482 - val_loss: 4.9946 - val_categorical_crossentropy: 7.2649 - val_my_top_k_acc: 0.3429 - lr: 0.0064
# Epoch 39/256
# 34/34 [==============================] - 9s 257ms/step - loss: 4.9289 - categorical_crossentropy: 7.1571 - my_top_k_acc: 0.3425 - val_loss: 4.9512 - val_categorical_crossentropy: 7.1937 - val_my_top_k_acc: 0.3443 - lr: 0.0064
# Epoch 40/256
# 34/34 [==============================] - 12s 346ms/step - loss: 4.9181 - categorical_crossentropy: 7.1849 - my_top_k_acc: 0.3453 - val_loss: 4.9694 - val_categorical_crossentropy: 7.2426 - val_my_top_k_acc: 0.3430 - lr: 0.0064
# Epoch 41/256
# 34/34 [==============================] - 11s 314ms/step - loss: 4.8941 - categorical_crossentropy: 7.1609 - my_top_k_acc: 0.3494 - val_loss: 4.9293 - val_categorical_crossentropy: 7.2065 - val_my_top_k_acc: 0.3475 - lr: 0.0064
# Epoch 42/256
# 34/34 [==============================] - 9s 282ms/step - loss: 4.8630 - categorical_crossentropy: 7.2088 - my_top_k_acc: 0.3485 - val_loss: 4.9500 - val_categorical_crossentropy: 7.3110 - val_my_top_k_acc: 0.3456 - lr: 0.0064
# Epoch 43/256
# 34/34 [==============================] - 9s 262ms/step - loss: 4.8679 - categorical_crossentropy: 7.2259 - my_top_k_acc: 0.3534 - val_loss: 4.9523 - val_categorical_crossentropy: 7.2554 - val_my_top_k_acc: 0.3427 - lr: 0.0064
# Epoch 44/256
# 34/34 [==============================] - 12s 351ms/step - loss: 4.8564 - categorical_crossentropy: 7.2135 - my_top_k_acc: 0.3464 - val_loss: 4.9422 - val_categorical_crossentropy: 7.2873 - val_my_top_k_acc: 0.3438 - lr: 0.0064
# Epoch 45/256
# 34/34 [==============================] - 17s 499ms/step - loss: 4.8400 - categorical_crossentropy: 7.2212 - my_top_k_acc: 0.3519 - val_loss: 4.9523 - val_categorical_crossentropy: 7.2855 - val_my_top_k_acc: 0.3437 - lr: 0.0064
# Epoch 46/256
# 34/34 [==============================] - 18s 540ms/step - loss: 4.8353 - categorical_crossentropy: 7.2693 - my_top_k_acc: 0.3504 - val_loss: 4.9341 - val_categorical_crossentropy: 7.4104 - val_my_top_k_acc: 0.3494 - lr: 0.0064
# Epoch 47/256
# 34/34 [==============================] - 15s 451ms/step - loss: 4.8409 - categorical_crossentropy: 7.2239 - my_top_k_acc: 0.3547 - val_loss: 4.9078 - val_categorical_crossentropy: 7.2811 - val_my_top_k_acc: 0.3509 - lr: 0.0064
# Epoch 48/256
# 34/34 [==============================] - 11s 324ms/step - loss: 4.8418 - categorical_crossentropy: 7.2927 - my_top_k_acc: 0.3531 - val_loss: 4.9182 - val_categorical_crossentropy: 7.3294 - val_my_top_k_acc: 0.3436 - lr: 0.0064
# Epoch 49/256
# 34/34 [==============================] - 11s 323ms/step - loss: 4.8212 - categorical_crossentropy: 7.2760 - my_top_k_acc: 0.3526 - val_loss: 4.8965 - val_categorical_crossentropy: 7.3384 - val_my_top_k_acc: 0.3503 - lr: 0.0064
# Epoch 50/256
# 34/34 [==============================] - 11s 326ms/step - loss: 4.8173 - categorical_crossentropy: 7.2766 - my_top_k_acc: 0.3562 - val_loss: 4.9613 - val_categorical_crossentropy: 7.3692 - val_my_top_k_acc: 0.3423 - lr: 0.0064
# Epoch 51/256
# 34/34 [==============================] - 9s 273ms/step - loss: 4.8705 - categorical_crossentropy: 7.3181 - my_top_k_acc: 0.3469 - val_loss: 4.9268 - val_categorical_crossentropy: 7.3717 - val_my_top_k_acc: 0.3470 - lr: 0.0064
# Epoch 52/256
# 34/34 [==============================] - 9s 281ms/step - loss: 4.8339 - categorical_crossentropy: 7.3216 - my_top_k_acc: 0.3465 - val_loss: 4.9190 - val_categorical_crossentropy: 7.4312 - val_my_top_k_acc: 0.3486 - lr: 0.0064
# Epoch 53/256
# 34/34 [==============================] - 11s 339ms/step - loss: 4.8102 - categorical_crossentropy: 7.2761 - my_top_k_acc: 0.3513 - val_loss: 4.8749 - val_categorical_crossentropy: 7.3507 - val_my_top_k_acc: 0.3502 - lr: 0.0064
# Epoch 54/256
# 34/34 [==============================] - 12s 353ms/step - loss: 4.8075 - categorical_crossentropy: 7.3478 - my_top_k_acc: 0.3557 - val_loss: 4.9224 - val_categorical_crossentropy: 7.3834 - val_my_top_k_acc: 0.3439 - lr: 0.0064
# Epoch 55/256
# 34/34 [==============================] - 9s 259ms/step - loss: 4.8160 - categorical_crossentropy: 7.3508 - my_top_k_acc: 0.3505 - val_loss: 4.9019 - val_categorical_crossentropy: 7.3609 - val_my_top_k_acc: 0.3453 - lr: 0.0064
# Epoch 56/256
# 34/34 [==============================] - 10s 284ms/step - loss: 4.7890 - categorical_crossentropy: 7.3254 - my_top_k_acc: 0.3574 - val_loss: 4.8756 - val_categorical_crossentropy: 7.4242 - val_my_top_k_acc: 0.3508 - lr: 0.0064
# Epoch 57/256
# 34/34 [==============================] - 12s 344ms/step - loss: 4.7633 - categorical_crossentropy: 7.2759 - my_top_k_acc: 0.3593 - val_loss: 4.9037 - val_categorical_crossentropy: 7.4384 - val_my_top_k_acc: 0.3514 - lr: 0.0064
# Epoch 58/256
# 34/34 [==============================] - 11s 327ms/step - loss: 4.7720 - categorical_crossentropy: 7.3619 - my_top_k_acc: 0.3588 - val_loss: 4.8958 - val_categorical_crossentropy: 7.4245 - val_my_top_k_acc: 0.3467 - lr: 0.0064
# Epoch 59/256
# 34/34 [==============================] - 11s 324ms/step - loss: 4.7958 - categorical_crossentropy: 7.3435 - my_top_k_acc: 0.3552 - val_loss: 4.8917 - val_categorical_crossentropy: 7.4951 - val_my_top_k_acc: 0.3520 - lr: 0.0064
# Epoch 60/256
# 34/34 [==============================] - 9s 258ms/step - loss: 4.7792 - categorical_crossentropy: 7.3502 - my_top_k_acc: 0.3566 - val_loss: 4.8802 - val_categorical_crossentropy: 7.4349 - val_my_top_k_acc: 0.3532 - lr: 0.0064
# Epoch 61/256
# 34/34 [==============================] - 13s 376ms/step - loss: 4.7930 - categorical_crossentropy: 7.4019 - my_top_k_acc: 0.3541 - val_loss: 4.8759 - val_categorical_crossentropy: 7.4293 - val_my_top_k_acc: 0.3502 - lr: 0.0064
# Epoch 62/256
# 34/34 [==============================] - 12s 352ms/step - loss: 4.7463 - categorical_crossentropy: 7.3948 - my_top_k_acc: 0.3639 - val_loss: 4.8709 - val_categorical_crossentropy: 7.5087 - val_my_top_k_acc: 0.3522 - lr: 0.0054
# Epoch 63/256
# 34/34 [==============================] - 10s 292ms/step - loss: 4.7593 - categorical_crossentropy: 7.3670 - my_top_k_acc: 0.3594 - val_loss: 4.8796 - val_categorical_crossentropy: 7.5086 - val_my_top_k_acc: 0.3542 - lr: 0.0054
# Epoch 64/256
# 34/34 [==============================] - 11s 323ms/step - loss: 4.7379 - categorical_crossentropy: 7.3956 - my_top_k_acc: 0.3591 - val_loss: 4.8511 - val_categorical_crossentropy: 7.4251 - val_my_top_k_acc: 0.3509 - lr: 0.0054
# Epoch 65/256
# 34/34 [==============================] - 9s 258ms/step - loss: 4.7252 - categorical_crossentropy: 7.3400 - my_top_k_acc: 0.3619 - val_loss: 4.8452 - val_categorical_crossentropy: 7.4256 - val_my_top_k_acc: 0.3561 - lr: 0.0054
# Epoch 66/256
# 34/34 [==============================] - 12s 343ms/step - loss: 4.6987 - categorical_crossentropy: 7.3707 - my_top_k_acc: 0.3666 - val_loss: 4.8648 - val_categorical_crossentropy: 7.5457 - val_my_top_k_acc: 0.3538 - lr: 0.0054
# Epoch 67/256
# 34/34 [==============================] - 12s 344ms/step - loss: 4.6014 - categorical_crossentropy: 7.3446 - my_top_k_acc: 0.3789 - val_loss: 4.8683 - val_categorical_crossentropy: 7.5316 - val_my_top_k_acc: 0.3527 - lr: 0.0054
# Epoch 68/256
# 34/34 [==============================] - 12s 370ms/step - loss: 4.6469 - categorical_crossentropy: 7.3822 - my_top_k_acc: 0.3686 - val_loss: 4.8668 - val_categorical_crossentropy: 7.5020 - val_my_top_k_acc: 0.3533 - lr: 0.0054
# Epoch 69/256
# 34/34 [==============================] - 9s 280ms/step - loss: 4.5953 - categorical_crossentropy: 7.3484 - my_top_k_acc: 0.3758 - val_loss: 4.8619 - val_categorical_crossentropy: 7.5681 - val_my_top_k_acc: 0.3542 - lr: 0.0054
# Epoch 70/256
# 34/34 [==============================] - 11s 324ms/step - loss: 4.6549 - categorical_crossentropy: 7.4386 - my_top_k_acc: 0.3656 - val_loss: 4.8796 - val_categorical_crossentropy: 7.5934 - val_my_top_k_acc: 0.3525 - lr: 0.0054
# Epoch 71/256
# 34/34 [==============================] - 11s 327ms/step - loss: 4.6621 - categorical_crossentropy: 7.4140 - my_top_k_acc: 0.3650 - val_loss: 4.8737 - val_categorical_crossentropy: 7.5309 - val_my_top_k_acc: 0.3535 - lr: 0.0054
# Epoch 72/256
# 34/34 [==============================] - 9s 267ms/step - loss: 4.6670 - categorical_crossentropy: 7.4666 - my_top_k_acc: 0.3665 - val_loss: 4.8490 - val_categorical_crossentropy: 7.5744 - val_my_top_k_acc: 0.3531 - lr: 0.0054
# Epoch 73/256
# 34/34 [==============================] - 9s 280ms/step - loss: 4.6653 - categorical_crossentropy: 7.4162 - my_top_k_acc: 0.3696 - val_loss: 4.8241 - val_categorical_crossentropy: 7.4977 - val_my_top_k_acc: 0.3535 - lr: 0.0054
# Epoch 74/256
# 34/34 [==============================] - 9s 273ms/step - loss: 4.6276 - categorical_crossentropy: 7.4577 - my_top_k_acc: 0.3725 - val_loss: 4.8577 - val_categorical_crossentropy: 7.5374 - val_my_top_k_acc: 0.3564 - lr: 0.0054
# Epoch 75/256
# 34/34 [==============================] - 9s 280ms/step - loss: 4.6545 - categorical_crossentropy: 7.3755 - my_top_k_acc: 0.3738 - val_loss: 4.8496 - val_categorical_crossentropy: 7.5391 - val_my_top_k_acc: 0.3520 - lr: 0.0054
# Epoch 76/256
# 34/34 [==============================] - 12s 345ms/step - loss: 4.6431 - categorical_crossentropy: 7.4142 - my_top_k_acc: 0.3740 - val_loss: 4.8402 - val_categorical_crossentropy: 7.6254 - val_my_top_k_acc: 0.3591 - lr: 0.0054
# Epoch 77/256
# 34/34 [==============================] - 9s 282ms/step - loss: 4.6422 - categorical_crossentropy: 7.4679 - my_top_k_acc: 0.3675 - val_loss: 4.8554 - val_categorical_crossentropy: 7.6011 - val_my_top_k_acc: 0.3536 - lr: 0.0054
# Epoch 78/256
# 34/34 [==============================] - 11s 324ms/step - loss: 4.6696 - categorical_crossentropy: 7.4030 - my_top_k_acc: 0.3703 - val_loss: 4.8255 - val_categorical_crossentropy: 7.6184 - val_my_top_k_acc: 0.3586 - lr: 0.0054
# Epoch 79/256
# 34/34 [==============================] - 11s 325ms/step - loss: 4.6674 - categorical_crossentropy: 7.4678 - my_top_k_acc: 0.3664 - val_loss: 4.8462 - val_categorical_crossentropy: 7.6502 - val_my_top_k_acc: 0.3563 - lr: 0.0054
# Epoch 80/256
# 34/34 [==============================] - 11s 328ms/step - loss: 4.6704 - categorical_crossentropy: 7.5383 - my_top_k_acc: 0.3697 - val_loss: 4.8531 - val_categorical_crossentropy: 7.5868 - val_my_top_k_acc: 0.3528 - lr: 0.0054
# Epoch 81/256
# 34/34 [==============================] - 11s 336ms/step - loss: 4.6417 - categorical_crossentropy: 7.5283 - my_top_k_acc: 0.3731 - val_loss: 4.8553 - val_categorical_crossentropy: 7.6450 - val_my_top_k_acc: 0.3568 - lr: 0.0054
# Epoch 82/256
# 34/34 [==============================] - 10s 305ms/step - loss: 4.6514 - categorical_crossentropy: 7.4805 - my_top_k_acc: 0.3722 - val_loss: 4.8183 - val_categorical_crossentropy: 7.6569 - val_my_top_k_acc: 0.3560 - lr: 0.0045
# Epoch 83/256
# 34/34 [==============================] - 14s 417ms/step - loss: 4.6628 - categorical_crossentropy: 7.5313 - my_top_k_acc: 0.3669 - val_loss: 4.8049 - val_categorical_crossentropy: 7.5484 - val_my_top_k_acc: 0.3578 - lr: 0.0045
# Epoch 84/256
# 34/34 [==============================] - 12s 347ms/step - loss: 4.6582 - categorical_crossentropy: 7.4779 - my_top_k_acc: 0.3667 - val_loss: 4.8270 - val_categorical_crossentropy: 7.6582 - val_my_top_k_acc: 0.3575 - lr: 0.0045
# Epoch 85/256
# 34/34 [==============================] - 9s 277ms/step - loss: 4.6718 - categorical_crossentropy: 7.5482 - my_top_k_acc: 0.3690 - val_loss: 4.8563 - val_categorical_crossentropy: 7.6899 - val_my_top_k_acc: 0.3556 - lr: 0.0045
# Epoch 86/256
# 34/34 [==============================] - 11s 323ms/step - loss: 4.6473 - categorical_crossentropy: 7.5903 - my_top_k_acc: 0.3728 - val_loss: 4.8014 - val_categorical_crossentropy: 7.6070 - val_my_top_k_acc: 0.3645 - lr: 0.0045
# Epoch 87/256
# 34/34 [==============================] - 9s 256ms/step - loss: 4.6554 - categorical_crossentropy: 7.5888 - my_top_k_acc: 0.3726 - val_loss: 4.8138 - val_categorical_crossentropy: 7.6131 - val_my_top_k_acc: 0.3587 - lr: 0.0045
# Epoch 88/256
# 34/34 [==============================] - 12s 348ms/step - loss: 4.6639 - categorical_crossentropy: 7.5373 - my_top_k_acc: 0.3669 - val_loss: 4.8295 - val_categorical_crossentropy: 7.7554 - val_my_top_k_acc: 0.3562 - lr: 0.0045
# Epoch 89/256
# 34/34 [==============================] - 12s 361ms/step - loss: 4.6522 - categorical_crossentropy: 7.5854 - my_top_k_acc: 0.3694 - val_loss: 4.8209 - val_categorical_crossentropy: 7.6887 - val_my_top_k_acc: 0.3573 - lr: 0.0045
# Epoch 90/256
# 34/34 [==============================] - 9s 280ms/step - loss: 4.6549 - categorical_crossentropy: 7.5842 - my_top_k_acc: 0.3718 - val_loss: 4.8272 - val_categorical_crossentropy: 7.5806 - val_my_top_k_acc: 0.3573 - lr: 0.0045
# Epoch 91/256
# 34/34 [==============================] - 9s 268ms/step - loss: 4.6602 - categorical_crossentropy: 7.5872 - my_top_k_acc: 0.3707 - val_loss: 4.8231 - val_categorical_crossentropy: 7.7401 - val_my_top_k_acc: 0.3601 - lr: 0.0045
# Epoch 92/256
# 34/34 [==============================] - 11s 339ms/step - loss: 4.6768 - categorical_crossentropy: 7.5814 - my_top_k_acc: 0.3663 - val_loss: 4.8141 - val_categorical_crossentropy: 7.7310 - val_my_top_k_acc: 0.3645 - lr: 0.0045
# Epoch 93/256
# 34/34 [==============================] - 9s 280ms/step - loss: 4.6525 - categorical_crossentropy: 7.6284 - my_top_k_acc: 0.3717 - val_loss: 4.8481 - val_categorical_crossentropy: 7.7558 - val_my_top_k_acc: 0.3600 - lr: 0.0045
# Epoch 94/256
# 34/34 [==============================] - 11s 334ms/step - loss: 4.6221 - categorical_crossentropy: 7.5983 - my_top_k_acc: 0.3750 - val_loss: 4.8163 - val_categorical_crossentropy: 7.7614 - val_my_top_k_acc: 0.3585 - lr: 0.0045
# Epoch 95/256
# 34/34 [==============================] - 11s 324ms/step - loss: 4.6433 - categorical_crossentropy: 7.6083 - my_top_k_acc: 0.3713 - val_loss: 4.7837 - val_categorical_crossentropy: 7.7097 - val_my_top_k_acc: 0.3647 - lr: 0.0038
# Epoch 96/256
# 34/34 [==============================] - 11s 336ms/step - loss: 4.6356 - categorical_crossentropy: 7.5647 - my_top_k_acc: 0.3703 - val_loss: 4.7851 - val_categorical_crossentropy: 7.6854 - val_my_top_k_acc: 0.3652 - lr: 0.0038
# Epoch 97/256
# 34/34 [==============================] - 9s 257ms/step - loss: 4.6623 - categorical_crossentropy: 7.6223 - my_top_k_acc: 0.3739 - val_loss: 4.7667 - val_categorical_crossentropy: 7.6980 - val_my_top_k_acc: 0.3666 - lr: 0.0038
# Epoch 98/256
# 34/34 [==============================] - 12s 350ms/step - loss: 4.6460 - categorical_crossentropy: 7.6143 - my_top_k_acc: 0.3755 - val_loss: 4.7863 - val_categorical_crossentropy: 7.6861 - val_my_top_k_acc: 0.3646 - lr: 0.0038
# Epoch 99/256
# 34/34 [==============================] - 12s 347ms/step - loss: 4.5635 - categorical_crossentropy: 7.4931 - my_top_k_acc: 0.3833 - val_loss: 4.7923 - val_categorical_crossentropy: 7.7093 - val_my_top_k_acc: 0.3637 - lr: 0.0038
# Epoch 100/256
# 34/34 [==============================] - 11s 335ms/step - loss: 4.4941 - categorical_crossentropy: 7.5523 - my_top_k_acc: 0.3893 - val_loss: 4.8131 - val_categorical_crossentropy: 7.7556 - val_my_top_k_acc: 0.3620 - lr: 0.0038
# Epoch 101/256
# 34/34 [==============================] - 11s 324ms/step - loss: 4.5141 - categorical_crossentropy: 7.5489 - my_top_k_acc: 0.3831 - val_loss: 4.8146 - val_categorical_crossentropy: 7.7719 - val_my_top_k_acc: 0.3652 - lr: 0.0038
# Epoch 102/256
# 34/34 [==============================] - 11s 324ms/step - loss: 4.4804 - categorical_crossentropy: 7.5406 - my_top_k_acc: 0.3890 - val_loss: 4.8416 - val_categorical_crossentropy: 7.7652 - val_my_top_k_acc: 0.3545 - lr: 0.0038
# Epoch 103/256
# 34/34 [==============================] - 9s 263ms/step - loss: 4.5011 - categorical_crossentropy: 7.5924 - my_top_k_acc: 0.3850 - val_loss: 4.8149 - val_categorical_crossentropy: 7.7314 - val_my_top_k_acc: 0.3634 - lr: 0.0038
# Epoch 104/256
# 34/34 [==============================] - 10s 289ms/step - loss: 4.5057 - categorical_crossentropy: 7.5992 - my_top_k_acc: 0.3822 - val_loss: 4.7557 - val_categorical_crossentropy: 7.7285 - val_my_top_k_acc: 0.3667 - lr: 0.0038
# Epoch 105/256
# 34/34 [==============================] - 11s 333ms/step - loss: 4.5075 - categorical_crossentropy: 7.5807 - my_top_k_acc: 0.3851 - val_loss: 4.8023 - val_categorical_crossentropy: 7.7777 - val_my_top_k_acc: 0.3609 - lr: 0.0038
# Epoch 106/256
# 34/34 [==============================] - 12s 345ms/step - loss: 4.5106 - categorical_crossentropy: 7.6026 - my_top_k_acc: 0.3867 - val_loss: 4.8186 - val_categorical_crossentropy: 7.7321 - val_my_top_k_acc: 0.3644 - lr: 0.0038
# Epoch 107/256
# 34/34 [==============================] - 11s 329ms/step - loss: 4.4795 - categorical_crossentropy: 7.5657 - my_top_k_acc: 0.3882 - val_loss: 4.8244 - val_categorical_crossentropy: 7.8269 - val_my_top_k_acc: 0.3607 - lr: 0.0038
# Epoch 108/256
# 34/34 [==============================] - 11s 330ms/step - loss: 4.4961 - categorical_crossentropy: 7.5319 - my_top_k_acc: 0.3902 - val_loss: 4.7974 - val_categorical_crossentropy: 7.8007 - val_my_top_k_acc: 0.3627 - lr: 0.0038
# Epoch 109/256
# 34/34 [==============================] - 10s 305ms/step - loss: 4.4827 - categorical_crossentropy: 7.5563 - my_top_k_acc: 0.3908 - val_loss: 4.8272 - val_categorical_crossentropy: 7.8035 - val_my_top_k_acc: 0.3557 - lr: 0.0038
# Epoch 110/256
# 34/34 [==============================] - 12s 354ms/step - loss: 4.4902 - categorical_crossentropy: 7.5872 - my_top_k_acc: 0.3866 - val_loss: 4.8268 - val_categorical_crossentropy: 7.8196 - val_my_top_k_acc: 0.3611 - lr: 0.0038
# Epoch 111/256
# 34/34 [==============================] - 12s 353ms/step - loss: 4.4889 - categorical_crossentropy: 7.5514 - my_top_k_acc: 0.3882 - val_loss: 4.8214 - val_categorical_crossentropy: 7.8944 - val_my_top_k_acc: 0.3644 - lr: 0.0038
# Epoch 112/256
# 34/34 [==============================] - 11s 342ms/step - loss: 4.4997 - categorical_crossentropy: 7.5885 - my_top_k_acc: 0.3822 - val_loss: 4.7918 - val_categorical_crossentropy: 7.8305 - val_my_top_k_acc: 0.3656 - lr: 0.0038
# Epoch 113/256
# 34/34 [==============================] - 11s 330ms/step - loss: 4.4898 - categorical_crossentropy: 7.6643 - my_top_k_acc: 0.3877 - val_loss: 4.8335 - val_categorical_crossentropy: 7.8575 - val_my_top_k_acc: 0.3624 - lr: 0.0032
# Epoch 114/256
# 34/34 [==============================] - 11s 331ms/step - loss: 4.4637 - categorical_crossentropy: 7.6755 - my_top_k_acc: 0.3913 - val_loss: 4.7973 - val_categorical_crossentropy: 7.8989 - val_my_top_k_acc: 0.3655 - lr: 0.0032
# Epoch 115/256
# 34/34 [==============================] - 11s 331ms/step - loss: 4.5001 - categorical_crossentropy: 7.5980 - my_top_k_acc: 0.3847 - val_loss: 4.7861 - val_categorical_crossentropy: 7.8178 - val_my_top_k_acc: 0.3670 - lr: 0.0032
# Epoch 116/256
# 34/34 [==============================] - 10s 290ms/step - loss: 4.4967 - categorical_crossentropy: 7.6234 - my_top_k_acc: 0.3858 - val_loss: 4.8118 - val_categorical_crossentropy: 7.7737 - val_my_top_k_acc: 0.3591 - lr: 0.0032
# Epoch 117/256
# 34/34 [==============================] - 10s 294ms/step - loss: 4.5081 - categorical_crossentropy: 7.6340 - my_top_k_acc: 0.3818 - val_loss: 4.7775 - val_categorical_crossentropy: 7.8195 - val_my_top_k_acc: 0.3680 - lr: 0.0032
# Epoch 118/256
# 34/34 [==============================] - 10s 290ms/step - loss: 4.5187 - categorical_crossentropy: 7.6832 - my_top_k_acc: 0.3829 - val_loss: 4.8199 - val_categorical_crossentropy: 7.8823 - val_my_top_k_acc: 0.3635 - lr: 0.0032
# Epoch 119/256
# 34/34 [==============================] - 9s 273ms/step - loss: 4.4852 - categorical_crossentropy: 7.6748 - my_top_k_acc: 0.3913 - val_loss: 4.8036 - val_categorical_crossentropy: 7.8939 - val_my_top_k_acc: 0.3653 - lr: 0.0032
# Epoch 120/256
# 34/34 [==============================] - 10s 294ms/step - loss: 4.5087 - categorical_crossentropy: 7.7079 - my_top_k_acc: 0.3859 - val_loss: 4.7867 - val_categorical_crossentropy: 7.8121 - val_my_top_k_acc: 0.3685 - lr: 0.0032
# Epoch 121/256
# 34/34 [==============================] - 12s 349ms/step - loss: 4.4873 - categorical_crossentropy: 7.6751 - my_top_k_acc: 0.3873 - val_loss: 4.8025 - val_categorical_crossentropy: 7.9211 - val_my_top_k_acc: 0.3601 - lr: 0.0027
# Epoch 122/256
# 34/34 [==============================] - 11s 333ms/step - loss: 4.4936 - categorical_crossentropy: 7.6818 - my_top_k_acc: 0.3870 - val_loss: 4.7823 - val_categorical_crossentropy: 7.8292 - val_my_top_k_acc: 0.3695 - lr: 0.0027
# Epoch 123/256
# 34/34 [==============================] - 11s 336ms/step - loss: 4.4942 - categorical_crossentropy: 7.7138 - my_top_k_acc: 0.3916 - val_loss: 4.8141 - val_categorical_crossentropy: 7.9529 - val_my_top_k_acc: 0.3596 - lr: 0.0027
# Epoch 124/256
# 34/34 [==============================] - 11s 335ms/step - loss: 4.5072 - categorical_crossentropy: 7.7183 - my_top_k_acc: 0.3821 - val_loss: 4.7649 - val_categorical_crossentropy: 7.8091 - val_my_top_k_acc: 0.3681 - lr: 0.0027
# Epoch 125/256
# 34/34 [==============================] - 9s 273ms/step - loss: 4.4959 - categorical_crossentropy: 7.6824 - my_top_k_acc: 0.3850 - val_loss: 4.8217 - val_categorical_crossentropy: 7.9837 - val_my_top_k_acc: 0.3654 - lr: 0.0027
# Epoch 126/256
# 34/34 [==============================] - 10s 294ms/step - loss: 4.4679 - categorical_crossentropy: 7.7038 - my_top_k_acc: 0.3901 - val_loss: 4.7910 - val_categorical_crossentropy: 7.8542 - val_my_top_k_acc: 0.3654 - lr: 0.0027
# Epoch 127/256
# 34/34 [==============================] - 10s 294ms/step - loss: 4.4817 - categorical_crossentropy: 7.7310 - my_top_k_acc: 0.3890 - val_loss: 4.7679 - val_categorical_crossentropy: 7.9223 - val_my_top_k_acc: 0.3678 - lr: 0.0027
# Epoch 128/256
# 34/34 [==============================] - 11s 337ms/step - loss: 4.4885 - categorical_crossentropy: 7.6939 - my_top_k_acc: 0.3867 - val_loss: 4.7708 - val_categorical_crossentropy: 7.9641 - val_my_top_k_acc: 0.3655 - lr: 0.0027
# Epoch 129/256
# 34/34 [==============================] - 10s 287ms/step - loss: 4.4913 - categorical_crossentropy: 7.6744 - my_top_k_acc: 0.3879 - val_loss: 4.8164 - val_categorical_crossentropy: 7.9158 - val_my_top_k_acc: 0.3640 - lr: 0.0022
# Epoch 130/256
# 34/34 [==============================] - 12s 352ms/step - loss: 4.5115 - categorical_crossentropy: 7.7491 - my_top_k_acc: 0.3878 - val_loss: 4.7708 - val_categorical_crossentropy: 7.8666 - val_my_top_k_acc: 0.3698 - lr: 0.0022
# Epoch 131/256
# 34/34 [==============================] - 10s 290ms/step - loss: 4.4996 - categorical_crossentropy: 7.6625 - my_top_k_acc: 0.3925 - val_loss: 4.8147 - val_categorical_crossentropy: 7.9038 - val_my_top_k_acc: 0.3649 - lr: 0.0022
# Epoch 132/256
# 34/34 [==============================] - 11s 343ms/step - loss: 4.3735 - categorical_crossentropy: 7.6271 - my_top_k_acc: 0.4046 - val_loss: 4.7980 - val_categorical_crossentropy: 7.9587 - val_my_top_k_acc: 0.3670 - lr: 0.0022
# Epoch 133/256
# 34/34 [==============================] - 11s 330ms/step - loss: 4.3267 - categorical_crossentropy: 7.6276 - my_top_k_acc: 0.4043 - val_loss: 4.7641 - val_categorical_crossentropy: 7.8556 - val_my_top_k_acc: 0.3692 - lr: 0.0022
# Epoch 134/256
# 34/34 [==============================] - 9s 262ms/step - loss: 4.3600 - categorical_crossentropy: 7.6013 - my_top_k_acc: 0.3974 - val_loss: 4.7959 - val_categorical_crossentropy: 7.9088 - val_my_top_k_acc: 0.3612 - lr: 0.0022
# Epoch 135/256
# 34/34 [==============================] - 9s 282ms/step - loss: 4.3271 - categorical_crossentropy: 7.6248 - my_top_k_acc: 0.4042 - val_loss: 4.8071 - val_categorical_crossentropy: 7.9583 - val_my_top_k_acc: 0.3658 - lr: 0.0022
# Epoch 136/256
# 34/34 [==============================] - 12s 345ms/step - loss: 4.3290 - categorical_crossentropy: 7.6785 - my_top_k_acc: 0.4044 - val_loss: 4.7939 - val_categorical_crossentropy: 8.0008 - val_my_top_k_acc: 0.3674 - lr: 0.0022
# Epoch 137/256
# 34/34 [==============================] - 11s 326ms/step - loss: 4.3397 - categorical_crossentropy: 7.6107 - my_top_k_acc: 0.4076 - val_loss: 4.7978 - val_categorical_crossentropy: 7.9233 - val_my_top_k_acc: 0.3613 - lr: 0.0019
# Epoch 138/256
# 34/34 [==============================] - 9s 260ms/step - loss: 4.3545 - categorical_crossentropy: 7.6293 - my_top_k_acc: 0.4015 - val_loss: 4.7804 - val_categorical_crossentropy: 7.9431 - val_my_top_k_acc: 0.3717 - lr: 0.0019
# Epoch 139/256
# 34/34 [==============================] - 10s 284ms/step - loss: 4.3570 - categorical_crossentropy: 7.6544 - my_top_k_acc: 0.4030 - val_loss: 4.8068 - val_categorical_crossentropy: 7.9668 - val_my_top_k_acc: 0.3649 - lr: 0.0019
# Epoch 140/256
# 34/34 [==============================] - 10s 286ms/step - loss: 4.3549 - categorical_crossentropy: 7.6568 - my_top_k_acc: 0.4023 - val_loss: 4.7763 - val_categorical_crossentropy: 7.9854 - val_my_top_k_acc: 0.3709 - lr: 0.0019
# Epoch 141/256
# 34/34 [==============================] - 11s 331ms/step - loss: 4.3297 - categorical_crossentropy: 7.6595 - my_top_k_acc: 0.4019 - val_loss: 4.7610 - val_categorical_crossentropy: 7.9674 - val_my_top_k_acc: 0.3697 - lr: 0.0019
# Epoch 142/256
# 34/34 [==============================] - 11s 326ms/step - loss: 4.3294 - categorical_crossentropy: 7.6630 - my_top_k_acc: 0.4066 - val_loss: 4.8102 - val_categorical_crossentropy: 7.9596 - val_my_top_k_acc: 0.3638 - lr: 0.0019
# Epoch 143/256
# 34/34 [==============================] - 10s 294ms/step - loss: 4.3468 - categorical_crossentropy: 7.6889 - my_top_k_acc: 0.4050 - val_loss: 4.7730 - val_categorical_crossentropy: 7.9589 - val_my_top_k_acc: 0.3702 - lr: 0.0019
# Epoch 144/256
# 34/34 [==============================] - 12s 355ms/step - loss: 4.3711 - categorical_crossentropy: 7.6930 - my_top_k_acc: 0.3970 - val_loss: 4.7951 - val_categorical_crossentropy: 8.0331 - val_my_top_k_acc: 0.3673 - lr: 0.0019
# Epoch 145/256
# 34/34 [==============================] - 12s 353ms/step - loss: 4.3430 - categorical_crossentropy: 7.6634 - my_top_k_acc: 0.4103 - val_loss: 4.8072 - val_categorical_crossentropy: 7.9309 - val_my_top_k_acc: 0.3632 - lr: 0.0016
# Epoch 146/256
# 34/34 [==============================] - 12s 346ms/step - loss: 4.3667 - categorical_crossentropy: 7.7155 - my_top_k_acc: 0.4009 - val_loss: 4.7796 - val_categorical_crossentropy: 7.9835 - val_my_top_k_acc: 0.3671 - lr: 0.0016
# Epoch 147/256
# 34/34 [==============================] - 9s 279ms/step - loss: 4.3534 - categorical_crossentropy: 7.6786 - my_top_k_acc: 0.4032 - val_loss: 4.7564 - val_categorical_crossentropy: 8.0025 - val_my_top_k_acc: 0.3718 - lr: 0.0016
# Epoch 148/256
# 34/34 [==============================] - 11s 325ms/step - loss: 4.3544 - categorical_crossentropy: 7.7952 - my_top_k_acc: 0.4056 - val_loss: 4.8147 - val_categorical_crossentropy: 7.9864 - val_my_top_k_acc: 0.3637 - lr: 0.0016
# Epoch 149/256
# 34/34 [==============================] - 11s 336ms/step - loss: 4.3594 - categorical_crossentropy: 7.7093 - my_top_k_acc: 0.3994 - val_loss: 4.7889 - val_categorical_crossentropy: 7.9881 - val_my_top_k_acc: 0.3690 - lr: 0.0016
# Epoch 150/256
# 34/34 [==============================] - 10s 296ms/step - loss: 4.3672 - categorical_crossentropy: 7.6836 - my_top_k_acc: 0.4023 - val_loss: 4.7781 - val_categorical_crossentropy: 8.0401 - val_my_top_k_acc: 0.3667 - lr: 0.0016
# Epoch 151/256
# 34/34 [==============================] - 9s 279ms/step - loss: 4.3776 - categorical_crossentropy: 7.6980 - my_top_k_acc: 0.3996 - val_loss: 4.7886 - val_categorical_crossentropy: 8.0187 - val_my_top_k_acc: 0.3692 - lr: 0.0016
# Epoch 152/256
# 34/34 [==============================] - 9s 271ms/step - loss: 4.3581 - categorical_crossentropy: 7.7645 - my_top_k_acc: 0.4043 - val_loss: 4.8020 - val_categorical_crossentropy: 8.0050 - val_my_top_k_acc: 0.3681 - lr: 0.0016
# Epoch 153/256
# 34/34 [==============================] - 11s 338ms/step - loss: 4.3665 - categorical_crossentropy: 7.8320 - my_top_k_acc: 0.4029 - val_loss: 4.7507 - val_categorical_crossentropy: 7.9486 - val_my_top_k_acc: 0.3730 - lr: 0.0013
# Epoch 154/256
# 34/34 [==============================] - 9s 279ms/step - loss: 4.3559 - categorical_crossentropy: 7.7155 - my_top_k_acc: 0.4009 - val_loss: 4.7757 - val_categorical_crossentropy: 8.0434 - val_my_top_k_acc: 0.3700 - lr: 0.0013
# Epoch 155/256
# 34/34 [==============================] - 11s 337ms/step - loss: 4.3691 - categorical_crossentropy: 7.7237 - my_top_k_acc: 0.3998 - val_loss: 4.8018 - val_categorical_crossentropy: 8.0772 - val_my_top_k_acc: 0.3667 - lr: 0.0013
# Epoch 156/256
# 34/34 [==============================] - 11s 324ms/step - loss: 4.3954 - categorical_crossentropy: 7.7824 - my_top_k_acc: 0.3995 - val_loss: 4.7660 - val_categorical_crossentropy: 7.9563 - val_my_top_k_acc: 0.3710 - lr: 0.0013
# Epoch 157/256
# 34/34 [==============================] - 9s 266ms/step - loss: 4.3620 - categorical_crossentropy: 7.7270 - my_top_k_acc: 0.4017 - val_loss: 4.7985 - val_categorical_crossentropy: 7.9897 - val_my_top_k_acc: 0.3666 - lr: 0.0013
# Epoch 158/256
# 34/34 [==============================] - 10s 287ms/step - loss: 4.3747 - categorical_crossentropy: 7.7831 - my_top_k_acc: 0.4013 - val_loss: 4.7644 - val_categorical_crossentropy: 7.9995 - val_my_top_k_acc: 0.3711 - lr: 0.0013
# Epoch 159/256
# 34/34 [==============================] - 11s 340ms/step - loss: 4.3676 - categorical_crossentropy: 7.7878 - my_top_k_acc: 0.4011 - val_loss: 4.7467 - val_categorical_crossentropy: 7.9906 - val_my_top_k_acc: 0.3713 - lr: 0.0013
# Epoch 160/256
# 34/34 [==============================] - 11s 329ms/step - loss: 4.3669 - categorical_crossentropy: 7.7666 - my_top_k_acc: 0.3997 - val_loss: 4.8080 - val_categorical_crossentropy: 8.0244 - val_my_top_k_acc: 0.3645 - lr: 0.0013
# Epoch 161/256
# 34/34 [==============================] - 11s 327ms/step - loss: 4.3737 - categorical_crossentropy: 7.7675 - my_top_k_acc: 0.4011 - val_loss: 4.7534 - val_categorical_crossentropy: 8.0195 - val_my_top_k_acc: 0.3744 - lr: 0.0013
# Epoch 162/256
# 34/34 [==============================] - 9s 255ms/step - loss: 4.3793 - categorical_crossentropy: 7.8448 - my_top_k_acc: 0.3992 - val_loss: 4.7668 - val_categorical_crossentropy: 8.0077 - val_my_top_k_acc: 0.3689 - lr: 0.0013
# Epoch 163/256
# 34/34 [==============================] - 12s 350ms/step - loss: 4.3538 - categorical_crossentropy: 7.7349 - my_top_k_acc: 0.4071 - val_loss: 4.7744 - val_categorical_crossentropy: 8.0503 - val_my_top_k_acc: 0.3702 - lr: 0.0013
# Epoch 164/256
# 34/34 [==============================] - 12s 354ms/step - loss: 4.3513 - categorical_crossentropy: 7.7212 - my_top_k_acc: 0.4018 - val_loss: 4.7736 - val_categorical_crossentropy: 7.9523 - val_my_top_k_acc: 0.3730 - lr: 0.0013
# Epoch 165/256
# 34/34 [==============================] - 11s 339ms/step - loss: 4.2602 - categorical_crossentropy: 7.6625 - my_top_k_acc: 0.4124 - val_loss: 4.8083 - val_categorical_crossentropy: 8.1160 - val_my_top_k_acc: 0.3643 - lr: 0.0013
# Epoch 166/256
# 34/34 [==============================] - 11s 327ms/step - loss: 4.2310 - categorical_crossentropy: 7.6825 - my_top_k_acc: 0.4181 - val_loss: 4.7946 - val_categorical_crossentropy: 8.1191 - val_my_top_k_acc: 0.3682 - lr: 0.0013
# Epoch 167/256
# 34/34 [==============================] - 9s 258ms/step - loss: 4.2543 - categorical_crossentropy: 7.6730 - my_top_k_acc: 0.4112 - val_loss: 4.7754 - val_categorical_crossentropy: 7.9939 - val_my_top_k_acc: 0.3693 - lr: 0.0013
# Epoch 168/256
# 34/34 [==============================] - 9s 276ms/step - loss: 4.2081 - categorical_crossentropy: 7.6794 - my_top_k_acc: 0.4204 - val_loss: 4.7960 - val_categorical_crossentropy: 8.0524 - val_my_top_k_acc: 0.3690 - lr: 0.0011
# Epoch 169/256
# 34/34 [==============================] - 10s 283ms/step - loss: 4.2098 - categorical_crossentropy: 7.7187 - my_top_k_acc: 0.4195 - val_loss: 4.8135 - val_categorical_crossentropy: 8.1076 - val_my_top_k_acc: 0.3695 - lr: 0.0011
# Epoch 170/256
# 34/34 [==============================] - 11s 340ms/step - loss: 4.2492 - categorical_crossentropy: 7.6635 - my_top_k_acc: 0.4154 - val_loss: 4.8009 - val_categorical_crossentropy: 8.0858 - val_my_top_k_acc: 0.3678 - lr: 0.0011
# Epoch 171/256
# 34/34 [==============================] - 9s 260ms/step - loss: 4.2579 - categorical_crossentropy: 7.6879 - my_top_k_acc: 0.4164 - val_loss: 4.8040 - val_categorical_crossentropy: 8.0874 - val_my_top_k_acc: 0.3667 - lr: 0.0011
# Epoch 172/256
# 34/34 [==============================] - 9s 282ms/step - loss: 4.2314 - categorical_crossentropy: 7.6819 - my_top_k_acc: 0.4170 - val_loss: 4.7853 - val_categorical_crossentropy: 8.1125 - val_my_top_k_acc: 0.3692 - lr: 0.0011
# Epoch 173/256
# 34/34 [==============================] - 11s 342ms/step - loss: 4.2505 - categorical_crossentropy: 7.7243 - my_top_k_acc: 0.4115 - val_loss: 4.7927 - val_categorical_crossentropy: 8.0205 - val_my_top_k_acc: 0.3681 - lr: 0.0011
# Epoch 174/256
# 34/34 [==============================] - 9s 278ms/step - loss: 4.2171 - categorical_crossentropy: 7.6845 - my_top_k_acc: 0.4186 - val_loss: 4.7953 - val_categorical_crossentropy: 8.0687 - val_my_top_k_acc: 0.3658 - lr: 0.0011
# Epoch 175/256
# 34/34 [==============================] - 11s 328ms/step - loss: 4.2161 - categorical_crossentropy: 7.7168 - my_top_k_acc: 0.4199 - val_loss: 4.8014 - val_categorical_crossentropy: 8.0927 - val_my_top_k_acc: 0.3709 - lr: 0.0011
# Epoch 176/256
# 34/34 [==============================] - 9s 269ms/step - loss: 4.2530 - categorical_crossentropy: 7.7101 - my_top_k_acc: 0.4149 - val_loss: 4.7826 - val_categorical_crossentropy: 8.0991 - val_my_top_k_acc: 0.3701 - lr: 9.4027e-04
# Epoch 177/256
# 34/34 [==============================] - 10s 309ms/step - loss: 4.2567 - categorical_crossentropy: 7.7358 - my_top_k_acc: 0.4133 - val_loss: 4.7849 - val_categorical_crossentropy: 8.1121 - val_my_top_k_acc: 0.3697 - lr: 9.4027e-04
# Epoch 178/256
# 34/34 [==============================] - 11s 325ms/step - loss: 4.2395 - categorical_crossentropy: 7.6993 - my_top_k_acc: 0.4205 - val_loss: 4.8072 - val_categorical_crossentropy: 8.1183 - val_my_top_k_acc: 0.3665 - lr: 9.4027e-04
# Epoch 179/256
# 34/34 [==============================] - 11s 328ms/step - loss: 4.2687 - categorical_crossentropy: 7.7287 - my_top_k_acc: 0.4132 - val_loss: 4.7808 - val_categorical_crossentropy: 8.0858 - val_my_top_k_acc: 0.3693 - lr: 9.4027e-04
# Epoch 180/256
# 34/34 [==============================] - 11s 330ms/step - loss: 4.2476 - categorical_crossentropy: 7.7610 - my_top_k_acc: 0.4176 - val_loss: 4.7884 - val_categorical_crossentropy: 8.0674 - val_my_top_k_acc: 0.3713 - lr: 9.4027e-04
# Epoch 181/256
# 34/34 [==============================] - 11s 337ms/step - loss: 4.2441 - categorical_crossentropy: 7.8212 - my_top_k_acc: 0.4172 - val_loss: 4.8076 - val_categorical_crossentropy: 8.1392 - val_my_top_k_acc: 0.3620 - lr: 9.4027e-04
# Epoch 182/256
# 34/34 [==============================] - 9s 282ms/step - loss: 4.2637 - categorical_crossentropy: 7.7567 - my_top_k_acc: 0.4136 - val_loss: 4.7661 - val_categorical_crossentropy: 8.1238 - val_my_top_k_acc: 0.3698 - lr: 9.4027e-04
# Epoch 183/256
# 34/34 [==============================] - 11s 340ms/step - loss: 4.2747 - categorical_crossentropy: 7.7291 - my_top_k_acc: 0.4118 - val_loss: 4.7960 - val_categorical_crossentropy: 8.1651 - val_my_top_k_acc: 0.3712 - lr: 9.4027e-04
# Epoch 184/256
# 34/34 [==============================] - 10s 288ms/step - loss: 4.2713 - categorical_crossentropy: 7.7397 - my_top_k_acc: 0.4121 - val_loss: 4.8160 - val_categorical_crossentropy: 8.0827 - val_my_top_k_acc: 0.3677 - lr: 7.8983e-04
# Epoch 185/256
# 34/34 [==============================] - 9s 257ms/step - loss: 4.2534 - categorical_crossentropy: 7.8094 - my_top_k_acc: 0.4159 - val_loss: 4.7661 - val_categorical_crossentropy: 8.0056 - val_my_top_k_acc: 0.3715 - lr: 7.8983e-04
# Epoch 186/256
# 34/34 [==============================] - 9s 280ms/step - loss: 4.2745 - categorical_crossentropy: 7.8749 - my_top_k_acc: 0.4124 - val_loss: 4.7755 - val_categorical_crossentropy: 8.0900 - val_my_top_k_acc: 0.3709 - lr: 7.8983e-04
# Epoch 187/256
# 34/34 [==============================] - 11s 333ms/step - loss: 4.2671 - categorical_crossentropy: 7.7303 - my_top_k_acc: 0.4124 - val_loss: 4.8018 - val_categorical_crossentropy: 8.1473 - val_my_top_k_acc: 0.3641 - lr: 7.8983e-04
# Epoch 188/256
# 34/34 [==============================] - 11s 326ms/step - loss: 4.2991 - categorical_crossentropy: 7.7878 - my_top_k_acc: 0.4081 - val_loss: 4.8024 - val_categorical_crossentropy: 8.1510 - val_my_top_k_acc: 0.3703 - lr: 7.8983e-04
# Epoch 189/256
# 34/34 [==============================] - 9s 262ms/step - loss: 4.2956 - categorical_crossentropy: 7.7975 - my_top_k_acc: 0.4109 - val_loss: 4.8009 - val_categorical_crossentropy: 8.1875 - val_my_top_k_acc: 0.3689 - lr: 7.8983e-04
# Epoch 190/256
# 34/34 [==============================] - 12s 350ms/step - loss: 4.2669 - categorical_crossentropy: 7.7698 - my_top_k_acc: 0.4134 - val_loss: 4.7965 - val_categorical_crossentropy: 8.0756 - val_my_top_k_acc: 0.3695 - lr: 7.8983e-04
# Epoch 191/256
# 34/34 [==============================] - 10s 284ms/step - loss: 4.2936 - categorical_crossentropy: 7.8599 - my_top_k_acc: 0.4111 - val_loss: 4.7490 - val_categorical_crossentropy: 8.0407 - val_my_top_k_acc: 0.3730 - lr: 7.8983e-04
# Epoch 192/256
# 34/34 [==============================] - 9s 277ms/step - loss: 4.2702 - categorical_crossentropy: 7.7957 - my_top_k_acc: 0.4117 - val_loss: 4.7777 - val_categorical_crossentropy: 8.1649 - val_my_top_k_acc: 0.3691 - lr: 6.6345e-04
# Epoch 193/256
# 34/34 [==============================] - 11s 327ms/step - loss: 4.2704 - categorical_crossentropy: 7.7955 - my_top_k_acc: 0.4117 - val_loss: 4.8060 - val_categorical_crossentropy: 8.1890 - val_my_top_k_acc: 0.3685 - lr: 6.6345e-04
# Epoch 194/256
# 34/34 [==============================] - 9s 268ms/step - loss: 4.2869 - categorical_crossentropy: 7.8389 - my_top_k_acc: 0.4095 - val_loss: 4.7886 - val_categorical_crossentropy: 8.1680 - val_my_top_k_acc: 0.3719 - lr: 6.6345e-04
# Epoch 195/256
# 34/34 [==============================] - 12s 349ms/step - loss: 4.2889 - categorical_crossentropy: 7.8667 - my_top_k_acc: 0.4103 - val_loss: 4.7868 - val_categorical_crossentropy: 8.1193 - val_my_top_k_acc: 0.3667 - lr: 6.6345e-04
# Epoch 196/256
# 34/34 [==============================] - 12s 343ms/step - loss: 4.2617 - categorical_crossentropy: 7.7347 - my_top_k_acc: 0.4168 - val_loss: 4.7724 - val_categorical_crossentropy: 8.0630 - val_my_top_k_acc: 0.3708 - lr: 6.6345e-04
# Epoch 197/256
# 34/34 [==============================] - 12s 354ms/step - loss: 4.2493 - categorical_crossentropy: 7.7762 - my_top_k_acc: 0.4128 - val_loss: 4.7609 - val_categorical_crossentropy: 8.0966 - val_my_top_k_acc: 0.3715 - lr: 6.6345e-04
# Epoch 198/256
# 34/34 [==============================] - 11s 332ms/step - loss: 4.1967 - categorical_crossentropy: 7.8052 - my_top_k_acc: 0.4177 - val_loss: 4.7877 - val_categorical_crossentropy: 8.1188 - val_my_top_k_acc: 0.3685 - lr: 6.6345e-04
# Epoch 199/256
# 34/34 [==============================] - 9s 257ms/step - loss: 4.1699 - categorical_crossentropy: 7.8339 - my_top_k_acc: 0.4247 - val_loss: 4.8109 - val_categorical_crossentropy: 8.2046 - val_my_top_k_acc: 0.3684 - lr: 6.6345e-04
# Epoch 200/256
# 34/34 [==============================] - 12s 351ms/step - loss: 4.1736 - categorical_crossentropy: 7.7504 - my_top_k_acc: 0.4269 - val_loss: 4.8158 - val_categorical_crossentropy: 8.1511 - val_my_top_k_acc: 0.3663 - lr: 5.5730e-04
# Epoch 201/256
# 34/34 [==============================] - 10s 287ms/step - loss: 4.1720 - categorical_crossentropy: 7.7537 - my_top_k_acc: 0.4261 - val_loss: 4.8029 - val_categorical_crossentropy: 8.1777 - val_my_top_k_acc: 0.3674 - lr: 5.5730e-04
# Epoch 202/256
# 34/34 [==============================] - 11s 332ms/step - loss: 4.1704 - categorical_crossentropy: 7.7322 - my_top_k_acc: 0.4245 - val_loss: 4.8084 - val_categorical_crossentropy: 8.1373 - val_my_top_k_acc: 0.3675 - lr: 5.5730e-04
# Epoch 203/256
# 34/34 [==============================] - 11s 336ms/step - loss: 4.1818 - categorical_crossentropy: 7.7380 - my_top_k_acc: 0.4276 - val_loss: 4.8086 - val_categorical_crossentropy: 8.1621 - val_my_top_k_acc: 0.3678 - lr: 5.5730e-04
# Epoch 204/256
# 34/34 [==============================] - 11s 328ms/step - loss: 4.2040 - categorical_crossentropy: 7.7075 - my_top_k_acc: 0.4187 - val_loss: 4.7972 - val_categorical_crossentropy: 8.2078 - val_my_top_k_acc: 0.3703 - lr: 5.5730e-04
# Epoch 205/256
# 34/34 [==============================] - 9s 278ms/step - loss: 4.1655 - categorical_crossentropy: 7.7455 - my_top_k_acc: 0.4291 - val_loss: 4.7842 - val_categorical_crossentropy: 8.1258 - val_my_top_k_acc: 0.3668 - lr: 5.5730e-04
# Epoch 206/256
# 34/34 [==============================] - 10s 289ms/step - loss: 4.1898 - categorical_crossentropy: 7.7350 - my_top_k_acc: 0.4224 - val_loss: 4.8310 - val_categorical_crossentropy: 8.2350 - val_my_top_k_acc: 0.3660 - lr: 5.5730e-04
# Epoch 207/256
# 34/34 [==============================] - 11s 327ms/step - loss: 4.2086 - categorical_crossentropy: 7.7515 - my_top_k_acc: 0.4201 - val_loss: 4.7899 - val_categorical_crossentropy: 8.1630 - val_my_top_k_acc: 0.3675 - lr: 5.5730e-04
# Epoch 208/256
# 34/34 [==============================] - 9s 262ms/step - loss: 4.1897 - categorical_crossentropy: 7.7526 - my_top_k_acc: 0.4236 - val_loss: 4.7859 - val_categorical_crossentropy: 8.1313 - val_my_top_k_acc: 0.3667 - lr: 4.6813e-04
# Epoch 209/256
# 34/34 [==============================] - 10s 283ms/step - loss: 4.1876 - categorical_crossentropy: 7.7010 - my_top_k_acc: 0.4197 - val_loss: 4.8368 - val_categorical_crossentropy: 8.1990 - val_my_top_k_acc: 0.3652 - lr: 4.6813e-04
# Epoch 210/256
# 34/34 [==============================] - 13s 378ms/step - loss: 4.1876 - categorical_crossentropy: 7.8744 - my_top_k_acc: 0.4227 - val_loss: 4.7838 - val_categorical_crossentropy: 8.1255 - val_my_top_k_acc: 0.3681 - lr: 4.6813e-04
# Epoch 211/256
# 34/34 [==============================] - 11s 328ms/step - loss: 4.1954 - categorical_crossentropy: 7.8013 - my_top_k_acc: 0.4220 - val_loss: 4.8020 - val_categorical_crossentropy: 8.2375 - val_my_top_k_acc: 0.3698 - lr: 4.6813e-04
# Epoch 212/256
# 34/34 [==============================] - 9s 261ms/step - loss: 4.1948 - categorical_crossentropy: 7.8041 - my_top_k_acc: 0.4237 - val_loss: 4.8030 - val_categorical_crossentropy: 8.1055 - val_my_top_k_acc: 0.3694 - lr: 4.6813e-04
# Epoch 213/256
# 34/34 [==============================] - 12s 349ms/step - loss: 4.2031 - categorical_crossentropy: 7.8260 - my_top_k_acc: 0.4227 - val_loss: 4.8041 - val_categorical_crossentropy: 8.2094 - val_my_top_k_acc: 0.3698 - lr: 4.6813e-04
# Epoch 214/256
# 34/34 [==============================] - 10s 283ms/step - loss: 4.1577 - categorical_crossentropy: 7.7022 - my_top_k_acc: 0.4284 - val_loss: 4.7918 - val_categorical_crossentropy: 8.2215 - val_my_top_k_acc: 0.3745 - lr: 4.6813e-04
# Epoch 215/256
# 34/34 [==============================] - 11s 331ms/step - loss: 4.2022 - categorical_crossentropy: 7.8369 - my_top_k_acc: 0.4221 - val_loss: 4.7951 - val_categorical_crossentropy: 8.1300 - val_my_top_k_acc: 0.3632 - lr: 4.6813e-04
# Epoch 216/256
# 34/34 [==============================] - 11s 325ms/step - loss: 4.1895 - categorical_crossentropy: 7.7395 - my_top_k_acc: 0.4210 - val_loss: 4.8103 - val_categorical_crossentropy: 8.1805 - val_my_top_k_acc: 0.3699 - lr: 3.9323e-04
# Epoch 217/256
# 34/34 [==============================] - 10s 279ms/step - loss: 4.2065 - categorical_crossentropy: 7.6884 - my_top_k_acc: 0.4206 - val_loss: 4.7986 - val_categorical_crossentropy: 8.2134 - val_my_top_k_acc: 0.3680 - lr: 3.9323e-04
# Epoch 218/256
# 34/34 [==============================] - 10s 284ms/step - loss: 4.1893 - categorical_crossentropy: 7.8076 - my_top_k_acc: 0.4252 - val_loss: 4.7977 - val_categorical_crossentropy: 8.1701 - val_my_top_k_acc: 0.3686 - lr: 3.9323e-04
# Epoch 219/256
# 34/34 [==============================] - 11s 333ms/step - loss: 4.1933 - categorical_crossentropy: 7.7722 - my_top_k_acc: 0.4222 - val_loss: 4.8079 - val_categorical_crossentropy: 8.1804 - val_my_top_k_acc: 0.3662 - lr: 3.9323e-04
# Epoch 220/256
# 34/34 [==============================] - 11s 327ms/step - loss: 4.2078 - categorical_crossentropy: 7.7419 - my_top_k_acc: 0.4241 - val_loss: 4.7912 - val_categorical_crossentropy: 8.1504 - val_my_top_k_acc: 0.3728 - lr: 3.9323e-04
# Epoch 221/256
# 34/34 [==============================] - 11s 331ms/step - loss: 4.2113 - categorical_crossentropy: 7.8659 - my_top_k_acc: 0.4167 - val_loss: 4.8215 - val_categorical_crossentropy: 8.2019 - val_my_top_k_acc: 0.3671 - lr: 3.9323e-04
# Epoch 222/256
# 34/34 [==============================] - 9s 262ms/step - loss: 4.2157 - categorical_crossentropy: 7.8711 - my_top_k_acc: 0.4174 - val_loss: 4.7593 - val_categorical_crossentropy: 8.1771 - val_my_top_k_acc: 0.3726 - lr: 3.9323e-04
# Epoch 223/256
# 34/34 [==============================] - 11s 321ms/step - loss: 4.2201 - categorical_crossentropy: 7.8017 - my_top_k_acc: 0.4149 - val_loss: 4.8252 - val_categorical_crossentropy: 8.2013 - val_my_top_k_acc: 0.3634 - lr: 3.9323e-04
# Epoch 224/256
# 34/34 [==============================] - 9s 282ms/step - loss: 4.1885 - categorical_crossentropy: 7.7727 - my_top_k_acc: 0.4249 - val_loss: 4.8355 - val_categorical_crossentropy: 8.1942 - val_my_top_k_acc: 0.3657 - lr: 3.3031e-04
# Epoch 225/256
# 34/34 [==============================] - 9s 260ms/step - loss: 4.1875 - categorical_crossentropy: 7.7476 - my_top_k_acc: 0.4224 - val_loss: 4.7756 - val_categorical_crossentropy: 8.2411 - val_my_top_k_acc: 0.3732 - lr: 3.3031e-04
# Epoch 226/256
# 34/34 [==============================] - 12s 353ms/step - loss: 4.1916 - categorical_crossentropy: 7.7465 - my_top_k_acc: 0.4220 - val_loss: 4.7828 - val_categorical_crossentropy: 8.1942 - val_my_top_k_acc: 0.3687 - lr: 3.3031e-04
# Epoch 227/256
# 34/34 [==============================] - 12s 355ms/step - loss: 4.2092 - categorical_crossentropy: 7.8060 - my_top_k_acc: 0.4197 - val_loss: 4.8013 - val_categorical_crossentropy: 8.1396 - val_my_top_k_acc: 0.3699 - lr: 3.3031e-04
# Epoch 228/256
# 34/34 [==============================] - 9s 280ms/step - loss: 4.1944 - categorical_crossentropy: 7.8765 - my_top_k_acc: 0.4262 - val_loss: 4.8043 - val_categorical_crossentropy: 8.2718 - val_my_top_k_acc: 0.3723 - lr: 3.3031e-04
# Epoch 229/256
# 34/34 [==============================] - 11s 328ms/step - loss: 4.1889 - categorical_crossentropy: 7.8151 - my_top_k_acc: 0.4261 - val_loss: 4.7967 - val_categorical_crossentropy: 8.1843 - val_my_top_k_acc: 0.3701 - lr: 3.3031e-04
# Epoch 230/256
# 34/34 [==============================] - 11s 339ms/step - loss: 4.1656 - categorical_crossentropy: 7.8107 - my_top_k_acc: 0.4239 - val_loss: 4.8110 - val_categorical_crossentropy: 8.2277 - val_my_top_k_acc: 0.3675 - lr: 3.3031e-04
# Epoch 231/256
# 34/34 [==============================] - 9s 265ms/step - loss: 4.1451 - categorical_crossentropy: 7.8522 - my_top_k_acc: 0.4266 - val_loss: 4.7811 - val_categorical_crossentropy: 8.1989 - val_my_top_k_acc: 0.3724 - lr: 3.3031e-04
# Epoch 232/256
# 34/34 [==============================] - 10s 285ms/step - loss: 4.1241 - categorical_crossentropy: 7.8016 - my_top_k_acc: 0.4318 - val_loss: 4.8099 - val_categorical_crossentropy: 8.2886 - val_my_top_k_acc: 0.3655 - lr: 2.7746e-04
# Epoch 233/256
# 34/34 [==============================] - 12s 343ms/step - loss: 4.1487 - categorical_crossentropy: 7.8253 - my_top_k_acc: 0.4286 - val_loss: 4.8173 - val_categorical_crossentropy: 8.2278 - val_my_top_k_acc: 0.3674 - lr: 2.7746e-04
# Epoch 234/256
# 34/34 [==============================] - 11s 329ms/step - loss: 4.1306 - categorical_crossentropy: 7.7965 - my_top_k_acc: 0.4307 - val_loss: 4.8303 - val_categorical_crossentropy: 8.1873 - val_my_top_k_acc: 0.3619 - lr: 2.7746e-04
# Epoch 235/256
# 34/34 [==============================] - 11s 330ms/step - loss: 4.1368 - categorical_crossentropy: 7.7697 - my_top_k_acc: 0.4306 - val_loss: 4.7987 - val_categorical_crossentropy: 8.1849 - val_my_top_k_acc: 0.3744 - lr: 2.7746e-04
# Epoch 236/256
# 34/34 [==============================] - 12s 350ms/step - loss: 4.1478 - categorical_crossentropy: 7.7280 - my_top_k_acc: 0.4324 - val_loss: 4.8102 - val_categorical_crossentropy: 8.1894 - val_my_top_k_acc: 0.3652 - lr: 2.7746e-04
# Epoch 237/256
# 34/34 [==============================] - 9s 267ms/step - loss: 4.1407 - categorical_crossentropy: 7.7522 - my_top_k_acc: 0.4271 - val_loss: 4.8071 - val_categorical_crossentropy: 8.2658 - val_my_top_k_acc: 0.3700 - lr: 2.7746e-04
# Epoch 238/256
# 34/34 [==============================] - 12s 353ms/step - loss: 4.1192 - categorical_crossentropy: 7.7589 - my_top_k_acc: 0.4340 - val_loss: 4.7981 - val_categorical_crossentropy: 8.1912 - val_my_top_k_acc: 0.3722 - lr: 2.7746e-04
# Epoch 239/256
# 34/34 [==============================] - 12s 353ms/step - loss: 4.1548 - categorical_crossentropy: 7.7355 - my_top_k_acc: 0.4278 - val_loss: 4.8334 - val_categorical_crossentropy: 8.2515 - val_my_top_k_acc: 0.3617 - lr: 2.7746e-04
# Epoch 240/256
# 34/34 [==============================] - 10s 287ms/step - loss: 4.1635 - categorical_crossentropy: 7.8019 - my_top_k_acc: 0.4257 - val_loss: 4.8182 - val_categorical_crossentropy: 8.2404 - val_my_top_k_acc: 0.3662 - lr: 2.3307e-04
# Epoch 241/256
# 34/34 [==============================] - 11s 330ms/step - loss: 4.1511 - categorical_crossentropy: 7.7558 - my_top_k_acc: 0.4289 - val_loss: 4.8006 - val_categorical_crossentropy: 8.1829 - val_my_top_k_acc: 0.3693 - lr: 2.3307e-04
# Epoch 242/256
# 34/34 [==============================] - 11s 331ms/step - loss: 4.1519 - categorical_crossentropy: 7.8132 - my_top_k_acc: 0.4256 - val_loss: 4.7751 - val_categorical_crossentropy: 8.1819 - val_my_top_k_acc: 0.3715 - lr: 2.3307e-04
# Epoch 243/256
# 34/34 [==============================] - 10s 290ms/step - loss: 4.1352 - categorical_crossentropy: 7.8214 - my_top_k_acc: 0.4288 - val_loss: 4.8235 - val_categorical_crossentropy: 8.2607 - val_my_top_k_acc: 0.3667 - lr: 2.3307e-04
# Epoch 244/256
# 34/34 [==============================] - 12s 355ms/step - loss: 4.1528 - categorical_crossentropy: 7.8295 - my_top_k_acc: 0.4254 - val_loss: 4.8007 - val_categorical_crossentropy: 8.1463 - val_my_top_k_acc: 0.3715 - lr: 2.3307e-04
# Epoch 245/256
# 34/34 [==============================] - 12s 347ms/step - loss: 4.1624 - categorical_crossentropy: 7.8677 - my_top_k_acc: 0.4278 - val_loss: 4.8083 - val_categorical_crossentropy: 8.2640 - val_my_top_k_acc: 0.3665 - lr: 2.3307e-04
# Epoch 246/256
# 34/34 [==============================] - 11s 331ms/step - loss: 4.1492 - categorical_crossentropy: 7.7956 - my_top_k_acc: 0.4284 - val_loss: 4.8185 - val_categorical_crossentropy: 8.2925 - val_my_top_k_acc: 0.3679 - lr: 2.3307e-04
# Epoch 247/256
# 34/34 [==============================] - 11s 330ms/step - loss: 4.1189 - categorical_crossentropy: 7.7517 - my_top_k_acc: 0.4334 - val_loss: 4.8188 - val_categorical_crossentropy: 8.2624 - val_my_top_k_acc: 0.3662 - lr: 2.3307e-04
# Epoch 248/256
# 34/34 [==============================] - 9s 267ms/step - loss: 4.1681 - categorical_crossentropy: 7.8479 - my_top_k_acc: 0.4270 - val_loss: 4.8017 - val_categorical_crossentropy: 8.2305 - val_my_top_k_acc: 0.3691 - lr: 1.9578e-04
# Epoch 249/256
# 34/34 [==============================] - 11s 333ms/step - loss: 4.1514 - categorical_crossentropy: 7.7222 - my_top_k_acc: 0.4256 - val_loss: 4.8109 - val_categorical_crossentropy: 8.2495 - val_my_top_k_acc: 0.3690 - lr: 1.9578e-04
# Epoch 250/256
# 34/34 [==============================] - 10s 290ms/step - loss: 4.1634 - categorical_crossentropy: 7.7166 - my_top_k_acc: 0.4286 - val_loss: 4.8067 - val_categorical_crossentropy: 8.2119 - val_my_top_k_acc: 0.3678 - lr: 1.9578e-04
# Epoch 251/256
# 34/34 [==============================] - 11s 330ms/step - loss: 4.1607 - categorical_crossentropy: 7.8291 - my_top_k_acc: 0.4291 - val_loss: 4.8104 - val_categorical_crossentropy: 8.2930 - val_my_top_k_acc: 0.3666 - lr: 1.9578e-04
# Epoch 252/256
# 34/34 [==============================] - 11s 333ms/step - loss: 4.1602 - categorical_crossentropy: 7.8565 - my_top_k_acc: 0.4247 - val_loss: 4.8270 - val_categorical_crossentropy: 8.1810 - val_my_top_k_acc: 0.3688 - lr: 1.9578e-04
# Epoch 253/256
# 34/34 [==============================] - 9s 272ms/step - loss: 4.1642 - categorical_crossentropy: 7.7607 - my_top_k_acc: 0.4305 - val_loss: 4.8013 - val_categorical_crossentropy: 8.2419 - val_my_top_k_acc: 0.3708 - lr: 1.9578e-04
# Epoch 254/256
# 34/34 [==============================] - 12s 355ms/step - loss: 4.1751 - categorical_crossentropy: 7.8404 - my_top_k_acc: 0.4218 - val_loss: 4.7943 - val_categorical_crossentropy: 8.2307 - val_my_top_k_acc: 0.3689 - lr: 1.9578e-04
# Epoch 255/256
# 34/34 [==============================] - 11s 319ms/step - loss: 4.1788 - categorical_crossentropy: 7.8912 - my_top_k_acc: 0.4215 - val_loss: 4.7845 - val_categorical_crossentropy: 8.1727 - val_my_top_k_acc: 0.3750 - lr: 1.9578e-04
# Epoch 256/256
# 34/34 [==============================] - 9s 273ms/step - loss: 4.1722 - categorical_crossentropy: 7.8005 - my_top_k_acc: 0.4218 - val_loss: 4.8144 - val_categorical_crossentropy: 8.2675 - val_my_top_k_acc: 0.3674 - lr: 1.6445e-04

# %%
history_callback.history.keys()
# Out:
# dict_keys(['loss', 'categorical_crossentropy', 'my_top_k_acc', 'val_loss', 'val_categorical_crossentropy', 'val_my_top_k_acc', 'lr'])

# %%
lr = history_callback.history["lr"];    lr = np.array(lr[:1]+lr);

# %%
loss_his = []
loss_his.append( np.array( h1[0:1]+ history_callback.history["loss"] ) )
loss_his.append( np.array( h1[2:]+ history_callback.history["my_top_k_acc"] ) )
loss_his.append( np.array( h2[0:1]+ history_callback.history["val_loss"] ) )
loss_his.append( np.array( h2[2:]+ history_callback.history["val_my_top_k_acc"] ) )

# %%
##### Correct rate of validation in the training period  ######
print(loss_his[3][-4:].tolist())
100*np.mean(loss_his[3][-4:])
# Out:
# [0.3708338439464569, 0.368896484375, 0.3749527335166931, 0.36742377281188965]
# 37.05267086625099

# %%
model.save_weights('./saved_model/model_'+'{0:03d}'.format(ver) + '/checkpoint/')

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(16, 5)) # figure area
plt.subplot(1,2,1)
plt.plot(range(len(loss_his[0])),loss_his[0], color=[0.8, 0.8, 0.8])
plt.plot(range(len(loss_his[2])),loss_his[2], color=[0, 0, 0]);
plt.subplot(1,2,2)
plt.plot(range(len(loss_his[1])),loss_his[1], color=[0.8, 0.8, 0.8])
plt.plot(range(len(loss_his[3])),loss_his[3], color=[0, 0, 0]);

# %%
x, y = [],[]
for line in range(batch_size):
    dataset = preprocessing.sequence.TimeseriesGenerator(
        sents[line],         sents[line],
        length=time_step,    batch_size=1)
    for batch in dataset:
        X, Y = batch;
        x.extend(X[0]);      y.extend(Y)
x = np.reshape(x,((seq_length-time_step)*batch_size,time_step))
y = keras.utils.to_categorical(y, len(w_idx))

# %%
row_wise_sum  = tf.reduce_sum(tf.gather(y,  [0], axis = 1),axis=1)
valid = tf.where(tf.equal(row_wise_sum,0))
y0 = tf.gather(y,  tf.squeeze(valid), axis = 0);

# %%
x, y = [],[]
for line in range(len(sents)):
    for i in range(len(sents[line])-time_step):
        if np.sum(sents[line][i:i+time_step])==0:  continue
        x.append(sents[line][i:i+time_step])
        y.append(sents[line][i+time_step])

# %%
num_ana = 60

states, vocab = [],[]; n_0 = np.zeros(2);   first_w = np.zeros(num_ana);
for j in range(num_ana):
    k = len(x)-num_ana+j;  w_char = [];
    # k = j+100;  w_char = [];
    x_pred = x[k];   x_pred = np.reshape(x_pred,(1, time_step))
    for i in range(time_step):
        w_char.append(idx_to_word[x[k][i]])
    ##### RNN state prediction and converting it to str ######
    rnn_output, rnn_states = inter_output_model.predict(x_pred)
    states.append(rnn_states)
    vocab.append(idx_to_word[x_pred[0,-1]])
    ##### model prediction and converting it to str ######
    prediction = model.predict(x_pred, verbose=0)
    index = np.argsort(-prediction)[:,:10]
    result = ''
    for m in range(np.size(index)):
        result = result + idx_to_word[index[:,m].item()] + ' '
    #### first word detection #####
    n_0[0] = n_0[1];     n_0[1] = np.sum(x_pred == 0);
    if n_0[0] < n_0[1]:
        first_w[j] = 1;
    #### output ####
    char = ' '.join(w_char)
    print(char)
    print('    answer:'+str(idx_to_word[y[k]]))
    print('    prediction:'+str(result))
# Out:
# 1/1 [==============================] - 0s 205ms/step
# _ _ _ _ _ _ _ _ _ _ _ _ the bed is not
#     answer:made
#     prediction:a so at to the but only there in going
# 1/1 [==============================] - 0s 23ms/step
# _ _ _ _ _ _ _ _ _ _ _ the bed is not made
#     answer:but
#     prediction:a up the to it in him out for me
# 1/1 [==============================] - 0s 25ms/step
# _ _ _ _ _ _ _ _ _ _ the bed is not made but
#     answer:you
#     prediction:the a to it in with by at there all
# 1/1 [==============================] - 0s 22ms/step
# _ _ _ _ _ _ _ _ _ the bed is not made but you
#     answer:will
#     prediction:know are have will can must would do were think
# 1/1 [==============================] - 0s 25ms/step
# _ _ _ _ _ _ _ _ the bed is not made but you will
#     answer:find
#     prediction:not be have make never find know see excuse do
# 1/1 [==============================] - 0s 24ms/step
# _ _ _ _ _ _ _ the bed is not made but you will find
#     answer:plenty
#     prediction:a me out the it that yourself him you some
# 1/1 [==============================] - 0s 20ms/step
# _ _ _ _ _ _ the bed is not made but you will find plenty
#     answer:of
#     prediction:of to about that more from for too on all
# 1/1 [==============================] - 0s 23ms/step
# _ _ _ _ _ the bed is not made but you will find plenty of
#     answer:unk
#     prediction:the a it course your him money this my us
# 1/1 [==============================] - 0s 20ms/step
# _ _ _ _ the bed is not made but you will find plenty of unk
#     answer:there
#     prediction:and in to for at on that or of with
# 1/1 [==============================] - 0s 24ms/step
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ perhaps
#     answer:get
#     prediction:it the he i she you if they we there
# 1/1 [==============================] - 0s 23ms/step
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ perhaps get
#     answer:as
#     prediction:out the me a more it in there to along
# 1/1 [==============================] - 0s 25ms/step
# _ _ _ _ _ _ _ _ _ _ _ _ _ perhaps get as
#     answer:far
#     prediction:to i if he a the much for in well
# 1/1 [==============================] - 0s 24ms/step
# _ _ _ _ _ _ _ _ _ _ _ _ perhaps get as far
#     answer:as
#     prediction:as off more from back away above by beyond down
# 1/1 [==============================] - 0s 24ms/step
# _ _ _ _ _ _ _ _ _ _ _ perhaps get as far as
#     answer:the
#     prediction:you i they it we he the possible a this
# 1/1 [==============================] - 0s 25ms/step
# _ _ _ _ _ _ _ _ _ _ perhaps get as far as the
#     answer:unk
#     prediction:world other last man men first matter work others grounds
# 1/1 [==============================] - 0s 24ms/step
# _ _ _ _ _ _ _ _ _ perhaps get as far as the unk
#     answer:which
#     prediction:of is and was said i are were he in
# 1/1 [==============================] - 0s 20ms/step
# _ _ _ _ _ _ _ _ perhaps get as far as the unk which
#     answer:was
#     prediction:was is i he will had she would in does
# 1/1 [==============================] - 0s 26ms/step
# _ _ _ _ _ _ _ perhaps get as far as the unk which was
#     answer:to
#     prediction:a the not in at now so to all gone
# 1/1 [==============================] - 0s 24ms/step
# _ _ _ _ _ _ perhaps get as far as the unk which was to
#     answer:be
#     prediction:be the come go have a say her take get
# 1/1 [==============================] - 0s 22ms/step
# _ _ _ _ _ perhaps get as far as the unk which was to be
#     answer:begun
#     prediction:sure done found a the in of given seen heard
# 1/1 [==============================] - 0s 27ms/step
# _ _ _ _ perhaps get as far as the unk which was to be begun
#     answer:cutting
#     prediction:to with in for by at without when as and
# 1/1 [==============================] - 0s 23ms/step
# _ _ _ perhaps get as far as the unk which was to be begun cutting
#     answer:on
#     prediction:into up round and down from in with to by
# 1/1 [==============================] - 0s 33ms/step
# _ _ perhaps get as far as the unk which was to be begun cutting on
#     answer:the
#     prediction:the a his this shore that purpose their board dr
# 1/1 [==============================] - 0s 30ms/step
# _ perhaps get as far as the unk which was to be begun cutting on the
#     answer:tomorrow
#     prediction:other side road subject floor table sea deck ground occasion
# 1/1 [==============================] - 0s 29ms/step
# perhaps get as far as the unk which was to be begun cutting on the tomorrow
#     answer:or
#     prediction:morning and night side at afternoon evening day in but
# 1/1 [==============================] - 0s 32ms/step
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ it
#     answer:was
#     prediction:was is would will had seemed has must may did
# 1/1 [==============================] - 0s 35ms/step
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ it was
#     answer:hardly
#     prediction:a not the only all too an very so in
# 1/1 [==============================] - 0s 29ms/step
# _ _ _ _ _ _ _ _ _ _ _ _ _ it was hardly
#     answer:right
#     prediction:a possible to an less long more enough that worth
# 1/1 [==============================] - 0s 30ms/step
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ and
#     answer:that
#     prediction:i the when as he she in then so that
# 1/1 [==============================] - 0s 38ms/step
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ and that
#     answer:she
#     prediction:is was he she the it there i in of
# 1/1 [==============================] - 0s 31ms/step
# _ _ _ _ _ _ _ _ _ _ _ _ _ and that she
#     answer:was
#     prediction:had was could would did might should must is will
# 1/1 [==============================] - 0s 33ms/step
# _ _ _ _ _ _ _ _ _ _ _ _ and that she was
#     answer:perfectly
#     prediction:not so a very in to quite going the too
# 1/1 [==============================] - 0s 30ms/step
# _ _ _ _ _ _ _ _ _ _ _ and that she was perfectly
#     answer:free
#     prediction:convinced satisfied happy right good comfortable very well safe easy
# 1/1 [==============================] - 0s 21ms/step
# _ _ _ _ _ _ _ _ _ _ and that she was perfectly free
#     answer:from
#     prediction:of and to from with in for at she however
# 1/1 [==============================] - 0s 22ms/step
# _ _ _ _ _ _ _ _ _ and that she was perfectly free from
#     answer:any
#     prediction:being the dr having her a uppercross wishing his colonel
# 1/1 [==============================] - 0s 26ms/step
# _ _ _ _ _ _ _ _ and that she was perfectly free from any
#     answer:tendency
#     prediction:of thing body change time degree other kind advantage one
# 1/1 [==============================] - 0s 23ms/step
# _ _ _ _ _ _ _ and that she was perfectly free from any tendency
#     answer:to
#     prediction:to of in on for by and from before or
# 1/1 [==============================] - 0s 24ms/step
# _ _ _ _ _ _ and that she was perfectly free from any tendency to
#     answer:being
#     prediction:be make her see the have pay give believe know
# 1/1 [==============================] - 0s 24ms/step
# _ _ _ _ _ and that she was perfectly free from any tendency to being
#     answer:attached
#     prediction:in a out the with left at able so expected
# 1/1 [==============================] - 0s 27ms/step
# _ _ _ _ and that she was perfectly free from any tendency to being attached
#     answer:to
#     prediction:to by a and in her home the on of
# 1/1 [==============================] - 0s 21ms/step
# _ _ _ and that she was perfectly free from any tendency to being attached to
#     answer:me
#     prediction:her the him them herself dr me his jane a
# 1/1 [==============================] - 0s 22ms/step
# _ _ and that she was perfectly free from any tendency to being attached to me
#     answer:was
#     prediction:than and to but in that with the dr as
# 1/1 [==============================] - 0s 23ms/step
# _ and that she was perfectly free from any tendency to being attached to me was
#     answer:as
#     prediction:to not the very she that in a more enough
# 1/1 [==============================] - 0s 26ms/step
# and that she was perfectly free from any tendency to being attached to me was as
#     answer:much
#     prediction:to she much if soon a far the possible well
# 1/1 [==============================] - 0s 30ms/step
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ you
#     answer:could
#     prediction:are will have know can must do see would may
# 1/1 [==============================] - 0s 24ms/step
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ you could
#     answer:come
#     prediction:not see have get think hear find be make do
# 1/1 [==============================] - 0s 21ms/step
# _ _ _ _ _ _ _ _ _ _ _ _ _ you could come
#     answer:down
#     prediction:back out in to into down and the with home
# 1/1 [==============================] - 0s 22ms/step
# _ _ _ _ _ _ _ _ _ _ _ _ you could come down
#     answer:to
#     prediction:to the again and in with my here there your
# 1/1 [==============================] - 0s 24ms/step
# _ _ _ _ _ _ _ _ _ _ _ you could come down to
#     answer:the
#     prediction:the me you your see my him it her be
# 1/1 [==============================] - 0s 26ms/step
# _ _ _ _ _ _ _ _ _ _ you could come down to the
#     answer:office
#     prediction:house door old little other abbey end doctor top bottom
# 1/1 [==============================] - 0s 22ms/step
# _ _ _ _ _ _ _ _ _ you could come down to the office
#     answer:once
#     prediction:to door of i in and for with again at
# 1/1 [==============================] - 0s 27ms/step
# _ _ _ _ _ _ _ _ you could come down to the office once
#     answer:a
#     prediction:more to and in or i said again of but
# 1/1 [==============================] - 0s 24ms/step
# _ _ _ _ _ _ _ you could come down to the office once a
#     answer:day
#     prediction:little bit man couple great few long boy minute leg
# 1/1 [==============================] - 0s 27ms/step
# _ _ _ _ _ _ you could come down to the office once a day
#     answer:look
#     prediction:or and for after is in was a on i
# 1/1 [==============================] - 0s 24ms/step
# _ _ _ _ _ you could come down to the office once a day look
#     answer:over
#     prediction:at down for round of old over on and to
# 1/1 [==============================] - 0s 28ms/step
# _ _ _ _ you could come down to the office once a day look over
#     answer:a
#     prediction:the and to a it my he his there at
# 1/1 [==============================] - 0s 23ms/step
# _ _ _ you could come down to the office once a day look over a
#     answer:few
#     prediction:man little bit day few very week small couple hill
# 1/1 [==============================] - 0s 23ms/step
# _ _ you could come down to the office once a day look over a few
#     answer:unk
#     prediction:minutes days years hours lines moments weeks miles yards feet
# 1/1 [==============================] - 0s 25ms/step
# _ you could come down to the office once a day look over a few unk
#     answer:unk
#     prediction:and of in to on for at the he with
# 1/1 [==============================] - 0s 23ms/step
# you could come down to the office once a day look over a few unk unk
#     answer:an
#     prediction:and in of to the with but for on as

# %%
s_ori = np.concatenate(states,axis=0);

# %%
layer_dict = dict([(layer.name, layer) for layer in model.layers])
w_dcn = layer_dict['dense_1'].get_weights()

# %%
plt.hist(np.reshape(-w_dcn[0],[-1,]), bins=50);
plt.show()

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)
pca.fit(s_ori)
s_pca = pca.transform(s_ori)

# %%
s2_pca = np.NaN*np.zeros((2*len(first_w),2));  ii=0;
for i in range(len(first_w)):
    if first_w[i]==1:
        s2_pca[ii] = np.NaN;      ii = ii +1;
    s2_pca[ii,:] = s_pca[i,:];    ii = ii +1;

# %%
GABA_PC = -1;

# %%
inc_tmstep_valrate = [increments, time_step, train_val_rate,lr, gr_scale, dp_rate, min_fb_gr_b, p_cell, dp_through_rate, leaky_relu, p_relu_on, p_relu, sqrt_leak, max_fb_gr_b , cANN_DM, GABA_PC]

# %%
# ========== save in npz file ============
import joblib
dt =  (w_idx, idx_to_word, sents, loss_his, inc_tmstep_valrate)
joblib.dump(dt, './saved_model/np_'+'{0:03d}'.format(ver)+'.pkl', compress=3)
# Out:
# ['./saved_model/np_21045.pkl']

# %%
with open('./saved_model/tokenizer_'+'{0:03d}'.format(ver)+'.pkl', 'wb') as handle:
    joblib.dump(tokenizer, handle)
